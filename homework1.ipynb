# %% [markdown]
# ### **Structure of the Homework**
#
# The homework is divided into **four tasks**, and each task requires you to implement specific classes and functions. The tasks build upon concepts of web scraping, HTML parsing, document processing, and crawling.
#
# Here’s a breakdown of what is expected in each task:
#
# #### **Task 1: Artifact Caching System**
# - **Class**: `Artifact`
#   - Implement a class that can **download**, **store**, and **retrieve** digital content from a URL.
#   - This class should:
#     - Fetch content from a URL and store it in memory.
#     - Save the content to a local file to avoid redundant downloads.
#     - Retrieve the content from the local cache if it already exists.
# - **Methods**:
#   - `fetch_artifact()`: Downloads the content from the URL.
#   - `store_artifact()`: Stores the content locally in a unique file.
#   - `retrieve_artifact()`: Retrieves the content from the local cache.
#
# ---
#
# #### **Task 2: Smithsonian Snapshot Parser**
# - **Class**: `SmithsonianParser`
#   - Implement a class that parses HTML pages like [Smithsonian Snapshots](https://www.si.edu/newsdesk/snapshot/how-very-logical).
#   - This class should:
#     - Extract all links (`<a>` tags) and store them as a list of tuples.
#     - Extract all image URLs (`<img>` tags) and store them in a list.
#     - Clean the text from the page, removing unnecessary elements (scripts, styles).
# - **Methods**:
#   - `fetch_page()`: Downloads the HTML content of a page.
#   - `parse()`: Parses the content and extracts links, images, and cleaned text.
#   - `get_anchors()`, `get_images()`, and `get_text()`: Returns the extracted data.
#
# ---
#
# #### **Task 3: Text Analysis of Smithsonian Snapshot**
# - **Class**: `SmithsonianTextAnalyzer`
#   - Implement a class that analyzes the text content of a Smithsonian Snapshot page.
#   - This class should:
#     - Perform **word frequency analysis**.
#     - **Segment sentences** and split text properly.
#     - Clean the text to remove special characters and whitespace.
# - **Methods**:
#   - `analyze()`: Fetches the page content, processes the text, and generates word frequency statistics.
#   - `get_word_stats()`: Returns word frequency in the form of a `Counter` object.
#   - `split_into_sentences()`: Splits the text into sentences.
#
# ---
#
# #### **Task 4: Smithsonian Snapshot Web Crawler**
# - **Class**: `SmithsonianCrawler`
#   - Implement a web crawler that starts at the [Smithsonian Snapshots](https://www.si.edu/newsdesk/snapshots) page and crawls through linked snapshot articles.
#   - This class should:
#     - Crawl pages to a specified depth.
#     - Extract links, images, and cleaned text from each page.
#     - Return the results as soon as the page is processed.
# - **Methods**:
#   - `crawl()`: Recursively visits pages starting from a given URL.
#   - `crawl_generator()`: Generates content as the crawler processes each page.
#
# ---

# %% [markdown]
# ### Task 1: Archiving Virtual Artifacts - Preserving a Digital Museum
#
# #### 1.0.1. Task Description
# Imagine you are a data archivist working to preserve artifacts from the **Smithsonian Institution's digital collection**. Your job is to download, store, and manage different types of data (such as images, videos, and documents) to ensure they can be accessed later without repeated downloads.
#
# Use the [Smithsonian Institution Collections](https://www.si.edu/snapshot) as your source of artifacts. You are tasked with building a caching system that can store downloaded files in a structured way and retrieve them as needed.
#
# #### Tasks:
# 1. `fetch_artifact()`: Download content from the Smithsonian's collection page based on a provided URL. The method should return `True` if successful, or `False` if the download fails.
# 2. `store_artifact()`: Save the content of the artifact (text, image, etc.) in a local file system. Each artifact must be stored in its own unique file based on its URL.
# 3. `retrieve_artifact()`: Load an artifact from your local storage using its URL to ensure that content is cached correctly and avoid redundant downloads.
#
# #### Criteria for Success:
# - Different URLs must map to different files, even if they belong to the same domain.
# - Binary files (e.g., images) must be handled correctly without corruption.
# - Artifacts that are already stored locally should not be downloaded again.
#
# #### Link: [Smithsonian Institution Collections](https://www.si.edu/newsdesk/snapshot/what-good-boy)

# %%
import os
import hashlib
import requests

class Artifact:
    def __init__(self, url):
        self.url = url
        self.content = None
        self.filename = None

    def generate_filename(self):
        """
        Generates a unique and safe filename based on the URL.
        You will need to use a hash function (hint: hashlib).
        """
        url_hash = hashlib.md5(self.url.encode()).hexdigest()
        extension = os.path.splitext(self.url)[1]
        self.filename = url_hash + extension if extension else url_hash + ".artifact"

    def fetch_artifact(self):
        """
        Download the artifact from the given URL and store its content in memory.
        If the download is successful, return True. Otherwise, return False.
        """
        try:
            response = requests.get(self.url, stream=True)
            response.raise_for_status()
            self.content = response.content
            return True
        except (requests.exceptions.RequestException, IOError) as e:
            print(f"Failed to fetch artifact: {e}")
            return False

    def store_artifact(self, directory="artifact_cache"):
        """
        Store the artifact content in a local file in a cache directory.
        Ensure the file is stored with a unique name to avoid overwriting.
        """
        if not self.content:
            print("No content to store.")
            return False

        if not self.filename:
            self.generate_filename()

        if not os.path.exists(directory):
            os.makedirs(directory)

        filepath = os.path.join(directory, self.filename)
        try:
            with open(filepath, 'wb') as f:
                f.write(self.content)
            return True
        except IOError as e:
            print(f"Failed to store artifact: {e}")
            return False

    def retrieve_artifact(self, directory="artifact_cache"):
        """
        Retrieve the artifact from the local cache if it has been stored before.
        Return True if successful, False otherwise.
        """
        if not self.filename:
            self.generate_filename()

        filepath = os.path.join(directory, self.filename)
        if os.path.exists(filepath):
            try:
                with open(filepath, 'rb') as f:
                    self.content = f.read()
                return True
            except IOError as e:
                print(f"Failed to retrieve artifact: {e}")
                return False
        return False

# %%
artifact = Artifact("https://www.si.edu/newsdesk/snapshot/what-good-boy")

if artifact.fetch_artifact():
    artifact.store_artifact()

artifact.retrieve_artifact()
# Out:
# True

# %% [markdown]
# ### Task 2: Parsing Web Pages - Smithsonian Snapshot
#
# #### 2.0.2. Task Description
# For this task, you will be working with pages from the [Smithsonian Newsdesk Snapshot](https://www.si.edu/newsdesk/snapshot/how-very-logical). Your goal is to extract meaningful content such as links, images, and clean text from the page.
#
# You will need to:
# 1. Extract all hyperlinks (anchor tags) from the page and store them as a list of tuples `('link_text', 'absolute_url')`. Make sure to handle relative links by converting them to absolute URLs.
# 2. Collect all image URLs in a list. Ensure relative URLs are converted to absolute URLs.
# 3. Extract the plain text from the page, ignoring scripts, styles, and comments.
#
# #### Criteria for Success:
# - Extract all links as `('link_text', 'absolute_url')` and handle relative URLs.
# - Extract all image URLs as absolute URLs.
# - Clean and extract the main text from the document.
#
# #### Link: [How Very Logical](https://www.si.edu/newsdesk/snapshot/how-very-logical)

# %%
import requests
from bs4 import BeautifulSoup
from urllib.parse import urljoin

class SmithsonianParser:
    def __init__(self, url):
        self.url = url
        self.anchors = []
        self.images = []
        self.text = ""

    def fetch_page(self):
        """
        Fetch the HTML content of the given URL. If the request is successful,
        return the page content; otherwise, return None.
        """
        try:
            response = requests.get(self.url)
            response.raise_for_status()
            return response.text
        except requests.RequestException as e:
            print(f"Failed to fetch the page: {e}")
            return None

    def parse(self, html_content):
        """
        Parse the HTML content using BeautifulSoup. You need to:
        1. Extract all anchor tags and store them as ('link_text', 'absolute_url').
        2. Extract all image URLs and store them in a list.
        3. Extract clean, readable text from the page.
        """
        soup = BeautifulSoup(html_content, 'html.parser')

        self.anchors = [
            (a.get_text(strip=True), urljoin(self.url, a['href']))
            for a in soup.find_all('a', href=True)
        ]

        self.images = [
            urljoin(self.url, img['src'])
            for img in soup.find_all('img', src=True)
        ]

        for script_or_style in soup(['script', 'style']):
            script_or_style.decompose()

        self.text = soup.get_text(separator=' ').strip()

        self.text = ' '.join(self.text.split())

    def get_anchors(self):
        """
        Return the list of anchors extracted from the page.
        """
        return self.anchors

    def get_images(self):
        """
        Return the list of image URLs extracted from the page.
        """
        return self.images

    def get_text(self):
        """
        Return the cleaned text content extracted from the page.
        """
        return self.text

# %%
url = "https://www.si.edu/newsdesk/snapshot/how-very-logical"
parser = SmithsonianParser(url)

page_content = parser.fetch_page()
if page_content:
    parser.parse(page_content)

    print("Anchors:", parser.get_anchors())
    print("Images:", parser.get_images())
    print("Text:", parser.get_text())
# Out:
# Anchors: [('Skip to main content', 'https://www.si.edu/newsdesk/snapshot/how-very-logical#main-content'), ('My Visit', 'https://www.si.edu/myvisit'), ('Donate', 'http://go.si.edu/si-give'), ('Smithsonian Institution', 'https://www.si.edu/'), ('Visit', 'https://www.si.edu/visit'), ('Hours and Locations', 'https://www.si.edu/visit/hours'), ('Entry and Guidelines', 'https://www.si.edu/visit/tips'), ('Maps and Brochures', 'https://www.si.edu/visit/maps'), ('Dining and Shopping', 'https://www.si.edu/dining'), ('Accessibility', 'https://www.si.edu/visit/accessibility'), ('Visiting with Kids', 'https://www.si.edu/visit/kids'), ('Group Visits', 'https://www.si.edu/visit/groups'), ('Group Sales', 'https://www.si.edu/groupsales'), ("What's On", 'https://www.si.edu/whats-on'), ('Exhibitions', 'https://www.si.edu/exhibitions'), ('Current', 'https://www.si.edu/exhibitions'), ('Upcoming', 'https://www.si.edu/exhibitions/upcoming'), ('Past', 'https://www.si.edu/exhibitions/past'), ("Today's Events", 'https://www.si.edu/events/today'), ('Online Events', 'https://www.si.edu/events/online'), ('All Events', 'https://www.si.edu/events'), ('IMAX & Planetarium', 'https://www.si.edu/imax'), ('Explore', 'https://www.si.edu/explore'), ('- Art & Design', 'https://www.si.edu/explore/art'), ('- History & Culture', 'https://www.si.edu/explore/history'), ('- Science & Nature', 'https://www.si.edu/explore/science'), ('Collections', 'https://www.si.edu/collections'), ('Open Access', 'https://www.si.edu/openaccess'), ('Research Resources', 'https://www.si.edu/researchers'), ('Libraries', 'https://library.si.edu/'), ('Archives', 'https://www.si.edu/siasc'), ('Smithsonian Institution Archives', 'https://www.si.edu/siasc/si_archives'), ('Air and Space Museum', 'https://www.si.edu/siasc/nasm_archives'), ('Anacostia Community Museum', 'https://www.si.edu/siasc/acma'), ('American Art Museum', 'https://www.si.edu/siasc/saam'), ('Archives of American Art', 'https://www.si.edu/siasc/aaa'), ('Archives of American Gardens', 'https://www.si.edu/siasc/american_gardens'), ('American History Museum', 'https://www.si.edu/siasc/archives_center'), ('American Indian Museum', 'https://www.si.edu/siasc/nmai'), ('Asian Art Museum Archives', 'https://www.si.edu/siasc/freer_sackler'), ('Eliot Elisofon Photographic Archives, African Art', 'https://www.si.edu/siasc/eepa_nmafa'), ('Hirshhorn Archive', 'https://www.si.edu/siasc/hmsg_archive'), ('National Anthropological Archives', 'https://www.si.edu/siasc/naa'), ('National Portrait Gallery', 'https://www.si.edu/siasc/npg'), ('Ralph Rinzler Archives, Folklife', 'https://www.si.edu/siasc/rrfa_archive'), ("Libraries' Special Collections", 'https://www.si.edu/siasc/si_libraries'), ('Podcasts', 'https://www.si.edu/podcasts'), ('Mobile Apps', 'https://www.si.edu/mobile'), ('Learn', 'https://www.si.edu/learn'), ('For Caregivers', 'https://www.si.edu/learn/parents-and-caregivers'), ('For Educators', 'https://www.si.edu/educators'), ('Art & Design Resources', 'https://www.si.edu/educators/art-resources'), ('Science & Nature Resources', 'https://www.si.edu/educators/science-resources'), ('Social Studies & Civics Resources', 'https://www.si.edu/educators/social-studies-resources'), ('Professional Development', 'https://www.si.edu/educators/professional-development'), ('Events for Educators', 'https://www.si.edu/educators/events'), ('Field Trips', 'https://www.si.edu/visit/field-trip'), ('For Students', 'https://www.si.edu/learn/students'), ('For Academics', 'https://www.si.edu/learn/academics'), ('For Lifelong Learners', 'https://www.si.edu/learn/lifelong-learners'), ('Support Us', 'https://www.si.edu/support'), ('Become a Member', 'https://support.si.edu/site/Donation2/?df_id=18123&18123.donation=form1&s_formType=j&s_src=Z0000AW&s_subsrc=0000--eg--oa-oef--web--si-edu--top-nav--app--acq------support-nav--ow--&utm_campaign=0000--eg--oa-oef--web--si-edu--top-nav--app--acq------support-'), ('Renew Membership', 'https://support.si.edu/site/Donation2/ ...
# Images: ['https://www.si.edu/sites/all/themes/si_baseline/images/logos/logo.svg', 'https://www.si.edu/sites/default/files/snapshot-camera.jpg', 'https://www.si.edu/sites/default/files/snapshots/spock_ears_photo.jpg', 'https://www.si.edu/sites/default/files/styles/grid/public/snapshots/tree_severed_by_bullets_civil_war_photo.jpg?itok=MTKr6B52&c=e340ebec623a13e7b0b12492501f4571', 'https://logs1.smithsonian.museum/dcsuft0skadzpxvkk977nydg5_3r1t/njs.gif?dcsuri=/nojavascript&WT.js=No&WT.tv=10.4.23&dcssip=si.edu']
# Text: How Very Logical | Smithsonian Institution Skip to main content Search Search What is 2+5? Search My Visit Donate Smithsonian Institution Site Navigation Visit Hours and Locations Entry and Guidelines Maps and Brochures Dining and Shopping Accessibility Visiting with Kids Group Visits Group Sales What's On Exhibitions Current Upcoming Past Today's Events Online Events All Events IMAX & Planetarium Explore - Art & Design - History & Culture - Science & Nature Collections Open Access Research Resources Libraries Archives Smithsonian Institution Archives Air and Space Museum Anacostia Community Museum American Art Museum Archives of American Art Archives of American Gardens American History Museum American Indian Museum Asian Art Museum Archives Eliot Elisofon Photographic Archives, African Art Hirshhorn Archive National Anthropological Archives National Portrait Gallery Ralph Rinzler Archives, Folklife Libraries' Special Collections Podcasts Mobile Apps Learn For Caregivers For Educators Art & Design Resources Science & Nature Resources Social Studies & Civics Resources Professional Development Events for Educators Field Trips For Students For Academics For Lifelong Learners Support Us Become a Member Renew Membership Make a Gift Volunteer Behind-the-Scenes Digital Volunteers Museum Information Desk Smithsonian Call Center Docent Programs Participatory Science About Our Organization Board of Regents Members Committees Reading Room Bylaws, Policies and Procedures Schedules and Agendas Meeting Minutes Actions Webcasts Contact Museums and Zoo Research Centers Cultural Centers Education Centers General Counsel Legal History Internships Records Requests Reading Room Tort Claim Subpoenas & Testimonies Events Office of Human Resources Employee Benefits How to Apply Job Opportunities Job Seekers with Disabilities Frequently Asked Questions SI Civil Program Contact Us Equal Employment Office EEO Complaint Process Individuals with Disabilities Special Emphasis Program Supplier Diversity Program Doing Business with Us Policies and Procedures Additional Resources Sponsored Projects Policies Combating Trafficking in Persons Animal Care and Use Human Research Reports Internships Our Leadership Reports and Plans Annual Reports Metrics Dashboard Dashboard Home Virtual Smithsonian Public Engagement National Collections Research People & Operations One Smithsonian Strategic Plan Newsdesk News Releases Media Contacts Photos and Video Media Kits Fact Sheets Visitor Stats Secretary and Admin Bios Filming Requests Smithsonian Snapshot A peek into our collections, one object at a time How Very Logical October 17, 2023 Original Mr. Spock ear tips (A20220161000). Smithsonian photo by Eric Long. Pictured above are foam pointed ear tips that Leonard Nimoy wore in his role as Spock in the original 1960s Star Trek TV series, which aired on NBC from 1966 until 1969. Nimoy brought the prosthetics home as a personal memento of his role as the half-human, half-Vulcan science officer on the starship Enterprise. Until his death in 2015, the ear tips were displayed in Nimoy’s home in a box he made. Donated to the Smithsonian’s National Air and Space Museum by Nimoy’s children Adam and Julie and the Nimoy family, they are now on display in the museum’s Kenneth C. Griffin Exploring the Planets Gallery. Watch a video of the unboxing of the ear tips , read more about them , and view the museum’s Enterprise model that was also used in the original series. The ear tips were a gift of the Nimoy Family, in honor of Beit T'Shuvah and the Leonard Nimoy COPD Research Fund at UCLA. Collections Open Access Smithsonian Snapshot A Witness to War In a Civil War battle, bullets cut down an oak tree. More Smithsonian Snapshots » Footer logo Link to homepage Footer navigation Contact Us Job Opportunities Get Involved Inspector General Records Requests Accessibility EEO & Supplier Diversity Shop Online Host Your Event Press Room Privacy Terms of Use Social media links Facebook  ...

# %% [markdown]
# ### Task 3: Summarizing Smithsonian Snapshots
#
# #### 3.0.3. Task Description
# You will analyze the text content from one of the Smithsonian Snapshot pages, such as [How Very Logical](https://www.si.edu/newsdesk/snapshot/how-very-logical). Your task is to extract and analyze the text content from this page, focusing on the following:
#
# 1. **Extract key phrases**: Use basic natural language processing (NLP) techniques to identify the most frequently used words and key phrases from the main body of the text.
# 2. **Sentence segmentation**: Split the text into individual sentences, making sure to handle punctuation and proper sentence breaks appropriately.
# 3. **Clean the text**: Remove any extraneous characters, symbols, or whitespace.
#
# ### Tasks:
# 1. **Word Frequency Analysis**: Implement a method to count the frequency of each word in the page content, converting all words to lowercase.
# 2. **Sentence Splitting**: Implement a method to split the content into individual sentences, being mindful of punctuation and line breaks.
# 3. **Cleaning and Normalization**: Clean the text to remove any special characters or unnecessary whitespace.
#
# #### Criteria for Success:
# - The `get_word_stats()` method should return a frequency distribution of words as a `Counter` object.
# - Sentences should be extracted cleanly from the page’s main text.
# - The text should be normalized (lowercased, and special characters should be removed).
#
# #### Link: [How Very Logical](https://www.si.edu/newsdesk/snapshot/how-very-logical)

# %%
import requests
from bs4 import BeautifulSoup
import nltk
from nltk.tokenize import sent_tokenize, word_tokenize
from collections import Counter
import re

nltk.download('punkt')

class SmithsonianTextAnalyzer:
    def __init__(self, url):
        self.url = url
        self.text = ""
        self.sentences = []
        self.word_frequency = None

    def fetch_page(self):
        """
        Fetch the HTML content of the Smithsonian Snapshot page.
        Return the page content if successful, else return None.
        """
        try:
            response = requests.get(self.url)
            response.raise_for_status()
            return response.text
        except requests.RequestException as e:
            print(f"Error fetching the page: {e}")
            return None

    def clean_text(self, html_content):
        """
        Use BeautifulSoup to extract clean text from the HTML content.
        Remove scripts, styles, and special characters.
        """
        soup = BeautifulSoup(html_content, 'html.parser')
        
        for script in soup(["script", "style"]):
            script.decompose()
        
        text = soup.get_text()
        
        text = re.sub(r'\s+', ' ', text).strip()
        text = re.sub(r'[^\w\s]', '', text)
        
        self.text = text

    def split_into_sentences(self):
        """
        Use nltk's sentence tokenizer to split the cleaned text into sentences.
        If NLTK data is not available, use a simple regex-based approach.
        """
        try:
            nltk.data.find('tokenizers/punkt')
            self.sentences = sent_tokenize(self.text)
        except LookupError:
            print("NLTK Punkt tokenizer not found. Using simple regex-based sentence splitting.")
            self.sentences = re.split(r'(?<=[.!?])\s+', self.text)

    def get_word_stats(self):
        """
        Count the frequency of each word in the text. Return a Counter object.
        Ensure the text is lowercased for accurate counting.
        """
        try:
            nltk.data.find('tokenizers/punkt')
            words = word_tokenize(self.text.lower())
        except LookupError:
            print("NLTK word tokenizer not found. Using simple space-based word splitting.")
            words = self.text.lower().split()
        
        self.word_frequency = Counter(words)
        return self.word_frequency

    def analyze(self):
        """
        Orchestrate the fetching, cleaning, and analysis of the text from the page.
        - Fetch the HTML content.
        - Clean the text.
        - Split into sentences.
        - Get word frequency statistics.
        """
        html_content = self.fetch_page()
        if html_content:
            self.clean_text(html_content)
            self.split_into_sentences()
            self.get_word_stats()
            return True
        return False
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\eugen\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
url = "https://www.si.edu/newsdesk/snapshot/how-very-logical"
analyzer = SmithsonianTextAnalyzer(url)
    
if analyzer.analyze():
    print("Text Analysis Results:")
    print(f"Number of sentences: {len(analyzer.sentences)}")
    print(f"Number of unique words: {len(analyzer.word_frequency)}")
    print("Top 10 most frequent words:")
    for word, count in analyzer.word_frequency.most_common(10):
        print(f"{word}: {count}")
else:
    print("Analysis failed.")
# Out:
# NLTK Punkt tokenizer not found. Using simple regex-based sentence splitting.
# NLTK word tokenizer not found. Using simple space-based word splitting.
# Text Analysis Results:
# Number of sentences: 1
# Number of unique words: 339
# Top 10 most frequent words:
# the: 20
# and: 19
# of: 11
# a: 11
# smithsonian: 10
# in: 10
# to: 7
# ear: 5
# tips: 5
# nimoy: 5

# %% [markdown]
# ### Task 4: Building a Smithsonian Snapshots Crawler
#
# #### 4.0.4. Task Description
# In this task, you will create a **web crawler** that will start at the Smithsonian Snapshots page and follow links to gather and analyze the content from multiple snapshot pages. The Smithsonian Snapshot section contains multiple articles, and your crawler will explore these articles, download their content, and process the information.
#
# You will implement a web crawler that:
# 1. Starts at the [Smithsonian Snapshots Page](https://www.si.edu/snapshot).
# 2. Crawls through snapshot pages, extracting key information (links, images, and text) from each page.
# 3. Follows links from the initial page to other snapshot articles up to a specified depth.
# 4. Processes and stores the content from each crawled page.
#
# ### Tasks:
# 1. **Implement a Crawler**: Start crawling from the [Smithsonian Snapshots Page](https://www.si.edu/newsdesk/snapshots), gather links to snapshot articles, and visit each article.
# 2. **Content Extraction**: For each visited page, extract:
#    - Anchor tags (`'link_text', 'absolute_url'`).
#    - Image URLs (absolute URLs).
#    - Cleaned text content from the body of the article.
# 3. **Depth Control**: Implement a parameter to control the depth of the crawl (i.e., how many levels of links the crawler should follow).
# 4. **Yield Results**: Your crawler should return a **generator** that yields the results (text, links, images) as soon as a page is processed, rather than collecting everything before returning.
#
# ### Criteria for Success:
# - The crawler should respect the specified depth and only crawl the specified number of levels.
# - Each snapshot page should have its content (links, images, text) extracted and returned.
# - The crawler should handle relative links and convert them to absolute URLs.
# - The content should be cleaned and stored properly.
#
# #### Link: [Smithsonian Snapshots Page](https://www.si.edu/snapshot)
#
# # Make sure the total number of visited links doesn't exceed 10 links, or you might get 0 for the whole assignment due to long runtime when checking the links!

# %%
import requests
from bs4 import BeautifulSoup
from urllib.parse import urljoin
from typing import Optional, Dict, Generator
import time

class SmithsonianCrawler:
    def __init__(self, start_url: str, max_depth: int = 2) -> None:
        self.start_url: str = start_url
        self.max_depth: int = max_depth
        self.visited: set = set()

    def fetch_page(self, url: str) -> Optional[bytes]:
        try:
            response = requests.get(url)
            response.raise_for_status()
            return response.content
        except requests.RequestException as e:
            print(f"Error fetching {url}: {e}")
            return None

    def extract_content(self, html_content: bytes, base_url: str) -> Dict[str, Optional[str]]:
        soup = BeautifulSoup(html_content, 'html.parser')
        
        anchors = []
        for a in soup.find_all('a', href=True):
            link_text = a.text.strip()
            absolute_url = urljoin(base_url, a['href'])
            anchors.append((link_text, absolute_url))
        
        images = [urljoin(base_url, img['src']) for img in soup.find_all('img', src=True)]
        
        text = ' '.join([p.text for p in soup.find_all('p')])
        
        return {
            'anchors': anchors,
            'images': images,
            'text': text
        }

    def crawl(self, url: str, depth: int = 0) -> Generator[Dict[str, Optional[str]], None, None]:
        if depth > self.max_depth or url in self.visited or len(self.visited) >= 10:
            return
        
        self.visited.add(url)
        print("\n")
        print(f"Crawling {url} at depth {depth}...")
        print("\n")
        
        html_content = self.fetch_page(url)
        if html_content:
            content = self.extract_content(html_content, url)
            yield content
            
            for _, link in content['anchors']:
                if link.startswith(self.start_url):
                    yield from self.crawl(link, depth + 1)
        
        time.sleep(1)

    def crawl_generator(self) -> Generator[Dict[str, Optional[str]], None, None]:
        yield from self.crawl(self.start_url)

# %%
start_url = "https://www.si.edu/snapshot"
crawler = SmithsonianCrawler(start_url, max_depth=2)

for page_content in crawler.crawl_generator():
    print("Crawled Page Content:")
    print(f"Anchors: {page_content['anchors']}")
    print(f"Images: {page_content['images']}")
    print(f"Text (excerpt): {page_content['text']}")
# Out:
# Crawling https://www.si.edu/snapshot at depth 0...
#
#
# Crawled Page Content:
# Anchors: [('Skip to main content', 'https://www.si.edu/snapshot#main-content'), ('My Visit', 'https://www.si.edu/myvisit'), ('Donate', 'http://go.si.edu/si-give'), ('Smithsonian Institution', 'https://www.si.edu/'), ('Visit', 'https://www.si.edu/visit'), ('Hours and Locations', 'https://www.si.edu/visit/hours'), ('Entry and Guidelines', 'https://www.si.edu/visit/tips'), ('Maps and Brochures', 'https://www.si.edu/visit/maps'), ('Dining and Shopping', 'https://www.si.edu/dining'), ('Accessibility', 'https://www.si.edu/visit/accessibility'), ('Visiting with Kids', 'https://www.si.edu/visit/kids'), ('Group Visits', 'https://www.si.edu/visit/groups'), ('Group Sales', 'https://www.si.edu/groupsales'), ("What's On", 'https://www.si.edu/whats-on'), ('Exhibitions', 'https://www.si.edu/exhibitions'), ('Current', 'https://www.si.edu/exhibitions'), ('Upcoming', 'https://www.si.edu/exhibitions/upcoming'), ('Past', 'https://www.si.edu/exhibitions/past'), ("Today's Events", 'https://www.si.edu/events/today'), ('Online Events', 'https://www.si.edu/events/online'), ('All Events', 'https://www.si.edu/events'), ('IMAX & Planetarium', 'https://www.si.edu/imax'), ('Explore', 'https://www.si.edu/explore'), ('- Art & Design', 'https://www.si.edu/explore/art'), ('- History & Culture', 'https://www.si.edu/explore/history'), ('- Science & Nature', 'https://www.si.edu/explore/science'), ('Collections', 'https://www.si.edu/collections'), ('Open Access', 'https://www.si.edu/openaccess'), ('Research Resources', 'https://www.si.edu/researchers'), ('Libraries', 'https://library.si.edu/'), ('Archives', 'https://www.si.edu/siasc'), ('Smithsonian Institution Archives', 'https://www.si.edu/siasc/si_archives'), ('Air and Space Museum', 'https://www.si.edu/siasc/nasm_archives'), ('Anacostia Community Museum', 'https://www.si.edu/siasc/acma'), ('American Art Museum', 'https://www.si.edu/siasc/saam'), ('Archives of American Art', 'https://www.si.edu/siasc/aaa'), ('Archives of American Gardens', 'https://www.si.edu/siasc/american_gardens'), ('American History Museum', 'https://www.si.edu/siasc/archives_center'), ('American Indian Museum', 'https://www.si.edu/siasc/nmai'), ('Asian Art Museum Archives', 'https://www.si.edu/siasc/freer_sackler'), ('Eliot Elisofon Photographic Archives, African Art', 'https://www.si.edu/siasc/eepa_nmafa'), ('Hirshhorn Archive', 'https://www.si.edu/siasc/hmsg_archive'), ('National Anthropological Archives', 'https://www.si.edu/siasc/naa'), ('National Portrait Gallery', 'https://www.si.edu/siasc/npg'), ('Ralph Rinzler Archives, Folklife', 'https://www.si.edu/siasc/rrfa_archive'), ("Libraries' Special Collections", 'https://www.si.edu/siasc/si_libraries'), ('Podcasts', 'https://www.si.edu/podcasts'), ('Mobile Apps', 'https://www.si.edu/mobile'), ('Learn', 'https://www.si.edu/learn'), ('For Caregivers', 'https://www.si.edu/learn/parents-and-caregivers'), ('For Educators', 'https://www.si.edu/educators'), ('Art & Design Resources', 'https://www.si.edu/educators/art-resources'), ('Science & Nature Resources', 'https://www.si.edu/educators/science-resources'), ('Social Studies & Civics Resources', 'https://www.si.edu/educators/social-studies-resources'), ('Professional Development', 'https://www.si.edu/educators/professional-development'), ('Events for Educators', 'https://www.si.edu/educators/events'), ('Field Trips', 'https://www.si.edu/visit/field-trip'), ('For Students', 'https://www.si.edu/learn/students'), ('For Academics', 'https://www.si.edu/learn/academics'), ('For Lifelong Learners', 'https://www.si.edu/learn/lifelong-learners'), ('Support Us', 'https://www.si.edu/support'), ('Become a Member', 'https://support.si.edu/site/Donation2/?df_id=18123&18123.donation=form1&s_formType=j&s_src=Z0000AW&s_subsrc=0000--eg--oa-oef--web--si-edu--top-nav--app--acq------support-nav--ow--&utm_campaign=0000--eg--oa-oef--web--si-edu--top-nav--app--acq------support-'), ('Renew Membership', 'https://support.si.edu/site/Donation2/?df_id=18123&18123.donatio ...
# Images: ['https://www.si.edu/sites/all/themes/si_baseline/images/logos/logo.svg', 'https://www.si.edu/sites/default/files/snapshot-camera.jpg', 'https://www.si.edu/sites/default/files/styles/grid/public/snapshots/tree_severed_by_bullets_civil_war_photo.jpg?itok=MTKr6B52&c=e340ebec623a13e7b0b12492501f4571', 'https://www.si.edu/sites/default/files/styles/grid/public/snapshots/calder_fish_photo.jpg?itok=xg9mB7oP&c=ad55c2d53493a712904979e1a7aa05cb', 'https://www.si.edu/sites/default/files/styles/grid/public/snapshots/nato_stamp_phoo.jpg?itok=Rqqa50gr&c=b81f3af97b66f32d07318ea10559f62b', 'https://www.si.edu/sites/default/files/styles/grid/public/snapshots/nmaahc-4e89dbe04ee92_5001_civil_rights_act_1964_pen.jpg?itok=5QR-KYLB&c=dcc76bb27930cf6944fd2c9276c15cff', 'https://www.si.edu/sites/default/files/styles/grid/public/snapshots/cicada.gif?itok=QBrWjGyM&c=188df58bdcc23b6928540edd8289c8e7', 'https://www.si.edu/sites/default/files/styles/grid/public/snapshots/horse_nation_online_photo_0.jpg?itok=ucTbShxX&c=23365eea8b32e0549f7f3ac177615c79', 'https://www.si.edu/sites/default/files/styles/grid/public/snapshots/zen_motorcylce_photo_2.jpg?itok=TAe1l2kW&c=2dcac393c33d19d9424a901a68eb85a7', 'https://www.si.edu/sites/default/files/styles/grid/public/snapshots/lincolns_hat_photo.jpg?itok=ruG2OyJ5&c=5a198906b6feb9a9aca30e25efab9c31', 'https://www.si.edu/sites/default/files/styles/grid/public/snapshots/liebes_lurex_ad_photo.jpg?itok=HkMhp_Z_&c=552f62190c9ce556379e79d84f645ff9', 'https://www.si.edu/sites/default/files/styles/grid/public/snapshots/walcott_lodgepole_pine_photo.jpg?itok=rflho8P1&c=06b11a21fdaf2a95ca294029e2c313d5', 'https://www.si.edu/sites/default/files/styles/grid/public/snapshots/spock_ears_photo.jpg?itok=3BLOHA4U&c=b1872590ad683708720152f8b6002e55', 'https://www.si.edu/sites/default/files/styles/grid/public/snapshots/fossil_tooth_2_photo.jpg?itok=GLszCTmB&c=8d08bd5ee0bae6ee2d6dda703340161f', 'https://www.si.edu/sites/default/files/styles/grid/public/snapshots/mercury_telephone.jpg?itok=BTPcAIY_&c=bd3e50a8e8c757af4ca215a6556e5121', 'https://www.si.edu/sites/default/files/styles/grid/public/snapshots/gettysburg_photo.jpg?itok=VwkYfWK4&c=efb80ea2d4f3bf6670564e9969077e4d', 'https://www.si.edu/sites/default/files/styles/grid/public/snapshots/bob_newhart_grammy_photo_0.jpg?itok=kuwfKyBG&c=e4f06908849871452588b65ca051dca6', 'https://www.si.edu/sites/default/files/styles/grid/public/snapshots/harelem_hellfighters_photo.jpg?itok=4YkWzETe&c=abc41cf6838353902c6f3a4e94403f84', 'https://www.si.edu/sites/default/files/styles/grid/public/snapshots/sand_bottle_front_and_back.jpg?itok=dPC1BHCU&c=1bfd10b868818ff02731ac00d9b65a66', 'https://www.si.edu/sites/default/files/styles/grid/public/snapshots/nmai-milky_way_2.jpg?itok=Cc8LphSO&c=44fa290b4b1d43b384c38cfe92a42ed5', 'https://www.si.edu/sites/default/files/styles/grid/public/snapshots/hedy_lamarr_photo.jpg?itok=5f9nQP1F&c=3b0c991ebe61d641a4030d8aeab7e024', 'https://www.si.edu/sites/default/files/styles/grid/public/snapshots/freedmens_bureau_photo.jpg?itok=k90goWvl&c=c8d1b9cd92c5000377210be08015a2a4', 'https://www.si.edu/sites/default/files/styles/grid/public/snapshots/betty_white_photo.jpg?itok=TAUhD9y0&c=f97a926d000beac8b8adaea9a342e1c1', 'https://www.si.edu/sites/default/files/styles/grid/public/snapshots/grace_thorpe_photo_0.jpg?itok=McYJL2Ye&c=f801a06ff1ca89543366c65b0113b6ca', 'https://www.si.edu/sites/default/files/styles/grid/public/snapshots/corpse_bride_dog_scraps_photo.jpg?itok=_-HvwrVH&c=85a3e194cb2d16f0badd9b38415aeeea', 'https://www.si.edu/sites/default/files/styles/grid/public/snapshots/rolodex_photo.jpg?itok=-4yHdFGa&c=75ad59d4ef2f80305bd93fb17eeacec3', 'https://logs1.smithsonian.museum/dcsuft0skadzpxvkk977nydg5_3r1t/njs.gif?dcsuri=/nojavascript&WT.js=No&WT.tv=10.4.23&dcssip=si.edu']
# Text (excerpt): Link to homepage Sign up for Smithsonian e-news
#
#
# Crawling https://www.si.edu/snapshot#main-content at depth 1...
#
#
# Crawled Page Content:
# Anchors: [('Skip to main content', 'https://www.si.edu/snapshot#main-content'), ('My Visit', 'https://www.si.edu/myvisit'), ('Donate', 'http://go.si.edu/si-give'), ('Smithsonian Institution', 'https://www.si.edu/'), ('Visit', 'https://www.si.edu/visit'), ('Hours and Locations', 'https://www.si.edu/visit/hours'), ('Entry and Guidelines', 'https://www.si.edu/visit/tips'), ('Maps and Brochures', 'https://www.si.edu/visit/maps'), ('Dining and Shopping', 'https://www.si.edu/dining'), ('Accessibility', 'https://www.si.edu/visit/accessibility'), ('Visiting with Kids', 'https://www.si.edu/visit/kids'), ('Group Visits', 'https://www.si.edu/visit/groups'), ('Group Sales', 'https://www.si.edu/groupsales'), ("What's On", 'https://www.si.edu/whats-on'), ('Exhibitions', 'https://www.si.edu/exhibitions'), ('Current', 'https://www.si.edu/exhibitions'), ('Upcoming', 'https://www.si.edu/exhibitions/upcoming'), ('Past', 'https://www.si.edu/exhibitions/past'), ("Today's Events", 'https://www.si.edu/events/today'), ('Online Events', 'https://www.si.edu/events/online'), ('All Events', 'https://www.si.edu/events'), ('IMAX & Planetarium', 'https://www.si.edu/imax'), ('Explore', 'https://www.si.edu/explore'), ('- Art & Design', 'https://www.si.edu/explore/art'), ('- History & Culture', 'https://www.si.edu/explore/history'), ('- Science & Nature', 'https://www.si.edu/explore/science'), ('Collections', 'https://www.si.edu/collections'), ('Open Access', 'https://www.si.edu/openaccess'), ('Research Resources', 'https://www.si.edu/researchers'), ('Libraries', 'https://library.si.edu/'), ('Archives', 'https://www.si.edu/siasc'), ('Smithsonian Institution Archives', 'https://www.si.edu/siasc/si_archives'), ('Air and Space Museum', 'https://www.si.edu/siasc/nasm_archives'), ('Anacostia Community Museum', 'https://www.si.edu/siasc/acma'), ('American Art Museum', 'https://www.si.edu/siasc/saam'), ('Archives of American Art', 'https://www.si.edu/siasc/aaa'), ('Archives of American Gardens', 'https://www.si.edu/siasc/american_gardens'), ('American History Museum', 'https://www.si.edu/siasc/archives_center'), ('American Indian Museum', 'https://www.si.edu/siasc/nmai'), ('Asian Art Museum Archives', 'https://www.si.edu/siasc/freer_sackler'), ('Eliot Elisofon Photographic Archives, African Art', 'https://www.si.edu/siasc/eepa_nmafa'), ('Hirshhorn Archive', 'https://www.si.edu/siasc/hmsg_archive'), ('National Anthropological Archives', 'https://www.si.edu/siasc/naa'), ('National Portrait Gallery', 'https://www.si.edu/siasc/npg'), ('Ralph Rinzler Archives, Folklife', 'https://www.si.edu/siasc/rrfa_archive'), ("Libraries' Special Collections", 'https://www.si.edu/siasc/si_libraries'), ('Podcasts', 'https://www.si.edu/podcasts'), ('Mobile Apps', 'https://www.si.edu/mobile'), ('Learn', 'https://www.si.edu/learn'), ('For Caregivers', 'https://www.si.edu/learn/parents-and-caregivers'), ('For Educators', 'https://www.si.edu/educators'), ('Art & Design Resources', 'https://www.si.edu/educators/art-resources'), ('Science & Nature Resources', 'https://www.si.edu/educators/science-resources'), ('Social Studies & Civics Resources', 'https://www.si.edu/educators/social-studies-resources'), ('Professional Development', 'https://www.si.edu/educators/professional-development'), ('Events for Educators', 'https://www.si.edu/educators/events'), ('Field Trips', 'https://www.si.edu/visit/field-trip'), ('For Students', 'https://www.si.edu/learn/students'), ('For Academics', 'https://www.si.edu/learn/academics'), ('For Lifelong Learners', 'https://www.si.edu/learn/lifelong-learners'), ('Support Us', 'https://www.si.edu/support'), ('Become a Member', 'https://support.si.edu/site/Donation2/?df_id=18123&18123.donation=form1&s_formType=j&s_src=Z0000AW&s_subsrc=0000--eg--oa-oef--web--si-edu--top-nav--app--acq------support-nav--ow--&utm_campaign=0000--eg--oa-oef--web--si-edu--top-nav--app--acq------support-'), ('Renew Membership', 'https://support.si.edu/site/Donation2/?df_id=18123&18123.donatio ...
# Images: ['https://www.si.edu/sites/all/themes/si_baseline/images/logos/logo.svg', 'https://www.si.edu/sites/default/files/snapshot-camera.jpg', 'https://www.si.edu/sites/default/files/styles/grid/public/snapshots/tree_severed_by_bullets_civil_war_photo.jpg?itok=MTKr6B52&c=e340ebec623a13e7b0b12492501f4571', 'https://www.si.edu/sites/default/files/styles/grid/public/snapshots/calder_fish_photo.jpg?itok=xg9mB7oP&c=ad55c2d53493a712904979e1a7aa05cb', 'https://www.si.edu/sites/default/files/styles/grid/public/snapshots/nato_stamp_phoo.jpg?itok=Rqqa50gr&c=b81f3af97b66f32d07318ea10559f62b', 'https://www.si.edu/sites/default/files/styles/grid/public/snapshots/nmaahc-4e89dbe04ee92_5001_civil_rights_act_1964_pen.jpg?itok=5QR-KYLB&c=dcc76bb27930cf6944fd2c9276c15cff', 'https://www.si.edu/sites/default/files/styles/grid/public/snapshots/cicada.gif?itok=QBrWjGyM&c=188df58bdcc23b6928540edd8289c8e7', 'https://www.si.edu/sites/default/files/styles/grid/public/snapshots/horse_nation_online_photo_0.jpg?itok=ucTbShxX&c=23365eea8b32e0549f7f3ac177615c79', 'https://www.si.edu/sites/default/files/styles/grid/public/snapshots/zen_motorcylce_photo_2.jpg?itok=TAe1l2kW&c=2dcac393c33d19d9424a901a68eb85a7', 'https://www.si.edu/sites/default/files/styles/grid/public/snapshots/lincolns_hat_photo.jpg?itok=ruG2OyJ5&c=5a198906b6feb9a9aca30e25efab9c31', 'https://www.si.edu/sites/default/files/styles/grid/public/snapshots/liebes_lurex_ad_photo.jpg?itok=HkMhp_Z_&c=552f62190c9ce556379e79d84f645ff9', 'https://www.si.edu/sites/default/files/styles/grid/public/snapshots/walcott_lodgepole_pine_photo.jpg?itok=rflho8P1&c=06b11a21fdaf2a95ca294029e2c313d5', 'https://www.si.edu/sites/default/files/styles/grid/public/snapshots/spock_ears_photo.jpg?itok=3BLOHA4U&c=b1872590ad683708720152f8b6002e55', 'https://www.si.edu/sites/default/files/styles/grid/public/snapshots/fossil_tooth_2_photo.jpg?itok=GLszCTmB&c=8d08bd5ee0bae6ee2d6dda703340161f', 'https://www.si.edu/sites/default/files/styles/grid/public/snapshots/mercury_telephone.jpg?itok=BTPcAIY_&c=bd3e50a8e8c757af4ca215a6556e5121', 'https://www.si.edu/sites/default/files/styles/grid/public/snapshots/gettysburg_photo.jpg?itok=VwkYfWK4&c=efb80ea2d4f3bf6670564e9969077e4d', 'https://www.si.edu/sites/default/files/styles/grid/public/snapshots/bob_newhart_grammy_photo_0.jpg?itok=kuwfKyBG&c=e4f06908849871452588b65ca051dca6', 'https://www.si.edu/sites/default/files/styles/grid/public/snapshots/harelem_hellfighters_photo.jpg?itok=4YkWzETe&c=abc41cf6838353902c6f3a4e94403f84', 'https://www.si.edu/sites/default/files/styles/grid/public/snapshots/sand_bottle_front_and_back.jpg?itok=dPC1BHCU&c=1bfd10b868818ff02731ac00d9b65a66', 'https://www.si.edu/sites/default/files/styles/grid/public/snapshots/nmai-milky_way_2.jpg?itok=Cc8LphSO&c=44fa290b4b1d43b384c38cfe92a42ed5', 'https://www.si.edu/sites/default/files/styles/grid/public/snapshots/hedy_lamarr_photo.jpg?itok=5f9nQP1F&c=3b0c991ebe61d641a4030d8aeab7e024', 'https://www.si.edu/sites/default/files/styles/grid/public/snapshots/freedmens_bureau_photo.jpg?itok=k90goWvl&c=c8d1b9cd92c5000377210be08015a2a4', 'https://www.si.edu/sites/default/files/styles/grid/public/snapshots/betty_white_photo.jpg?itok=TAUhD9y0&c=f97a926d000beac8b8adaea9a342e1c1', 'https://www.si.edu/sites/default/files/styles/grid/public/snapshots/grace_thorpe_photo_0.jpg?itok=McYJL2Ye&c=f801a06ff1ca89543366c65b0113b6ca', 'https://www.si.edu/sites/default/files/styles/grid/public/snapshots/corpse_bride_dog_scraps_photo.jpg?itok=_-HvwrVH&c=85a3e194cb2d16f0badd9b38415aeeea', 'https://www.si.edu/sites/default/files/styles/grid/public/snapshots/rolodex_photo.jpg?itok=-4yHdFGa&c=75ad59d4ef2f80305bd93fb17eeacec3', 'https://logs1.smithsonian.museum/dcsuft0skadzpxvkk977nydg5_3r1t/njs.gif?dcsuri=/nojavascript&WT.js=No&WT.tv=10.4.23&dcssip=si.edu']
# Text (excerpt): Link to homepage Sign up for Smithsonian e-news
#
#
# Crawling https://www.si.edu/snapshot?page=1 at depth 2...
#
#
# Crawled Page Content:
# Anchors: [('Skip to main content', 'https://www.si.edu/snapshot?page=1#main-content'), ('My Visit', 'https://www.si.edu/myvisit'), ('Donate', 'http://go.si.edu/si-give'), ('Smithsonian Institution', 'https://www.si.edu/'), ('Visit', 'https://www.si.edu/visit'), ('Hours and Locations', 'https://www.si.edu/visit/hours'), ('Entry and Guidelines', 'https://www.si.edu/visit/tips'), ('Maps and Brochures', 'https://www.si.edu/visit/maps'), ('Dining and Shopping', 'https://www.si.edu/dining'), ('Accessibility', 'https://www.si.edu/visit/accessibility'), ('Visiting with Kids', 'https://www.si.edu/visit/kids'), ('Group Visits', 'https://www.si.edu/visit/groups'), ('Group Sales', 'https://www.si.edu/groupsales'), ("What's On", 'https://www.si.edu/whats-on'), ('Exhibitions', 'https://www.si.edu/exhibitions'), ('Current', 'https://www.si.edu/exhibitions'), ('Upcoming', 'https://www.si.edu/exhibitions/upcoming'), ('Past', 'https://www.si.edu/exhibitions/past'), ("Today's Events", 'https://www.si.edu/events/today'), ('Online Events', 'https://www.si.edu/events/online'), ('All Events', 'https://www.si.edu/events'), ('IMAX & Planetarium', 'https://www.si.edu/imax'), ('Explore', 'https://www.si.edu/explore'), ('- Art & Design', 'https://www.si.edu/explore/art'), ('- History & Culture', 'https://www.si.edu/explore/history'), ('- Science & Nature', 'https://www.si.edu/explore/science'), ('Collections', 'https://www.si.edu/collections'), ('Open Access', 'https://www.si.edu/openaccess'), ('Research Resources', 'https://www.si.edu/researchers'), ('Libraries', 'https://library.si.edu/'), ('Archives', 'https://www.si.edu/siasc'), ('Smithsonian Institution Archives', 'https://www.si.edu/siasc/si_archives'), ('Air and Space Museum', 'https://www.si.edu/siasc/nasm_archives'), ('Anacostia Community Museum', 'https://www.si.edu/siasc/acma'), ('American Art Museum', 'https://www.si.edu/siasc/saam'), ('Archives of American Art', 'https://www.si.edu/siasc/aaa'), ('Archives of American Gardens', 'https://www.si.edu/siasc/american_gardens'), ('American History Museum', 'https://www.si.edu/siasc/archives_center'), ('American Indian Museum', 'https://www.si.edu/siasc/nmai'), ('Asian Art Museum Archives', 'https://www.si.edu/siasc/freer_sackler'), ('Eliot Elisofon Photographic Archives, African Art', 'https://www.si.edu/siasc/eepa_nmafa'), ('Hirshhorn Archive', 'https://www.si.edu/siasc/hmsg_archive'), ('National Anthropological Archives', 'https://www.si.edu/siasc/naa'), ('National Portrait Gallery', 'https://www.si.edu/siasc/npg'), ('Ralph Rinzler Archives, Folklife', 'https://www.si.edu/siasc/rrfa_archive'), ("Libraries' Special Collections", 'https://www.si.edu/siasc/si_libraries'), ('Podcasts', 'https://www.si.edu/podcasts'), ('Mobile Apps', 'https://www.si.edu/mobile'), ('Learn', 'https://www.si.edu/learn'), ('For Caregivers', 'https://www.si.edu/learn/parents-and-caregivers'), ('For Educators', 'https://www.si.edu/educators'), ('Art & Design Resources', 'https://www.si.edu/educators/art-resources'), ('Science & Nature Resources', 'https://www.si.edu/educators/science-resources'), ('Social Studies & Civics Resources', 'https://www.si.edu/educators/social-studies-resources'), ('Professional Development', 'https://www.si.edu/educators/professional-development'), ('Events for Educators', 'https://www.si.edu/educators/events'), ('Field Trips', 'https://www.si.edu/visit/field-trip'), ('For Students', 'https://www.si.edu/learn/students'), ('For Academics', 'https://www.si.edu/learn/academics'), ('For Lifelong Learners', 'https://www.si.edu/learn/lifelong-learners'), ('Support Us', 'https://www.si.edu/support'), ('Become a Member', 'https://support.si.edu/site/Donation2/?df_id=18123&18123.donation=form1&s_formType=j&s_src=Z0000AW&s_subsrc=0000--eg--oa-oef--web--si-edu--top-nav--app--acq------support-nav--ow--&utm_campaign=0000--eg--oa-oef--web--si-edu--top-nav--app--acq------support-'), ('Renew Membership', 'https://support.si.edu/site/Donation2/?df_id=18123&18123. ...
# Images: ['https://www.si.edu/sites/all/themes/si_baseline/images/logos/logo.svg', 'https://www.si.edu/sites/default/files/snapshot-camera.jpg', 'https://www.si.edu/sites/default/files/styles/grid/public/snapshots/blue_morpho_butterfly_photo.jpg?itok=zoRoWx1F&c=8aa09ecfc3ac8b1dd0e1026384afd2f5', 'https://www.si.edu/sites/default/files/styles/grid/public/snapshots/eht_black_hole_sgr_a_photo.jpg?itok=0SldGUSw&c=f7e2b9b9d0a4a6291b2982cea76415f3', 'https://www.si.edu/sites/default/files/styles/grid/public/snapshots/sia-2004-47553.jpg?itok=F9BLrmM2&c=582c9f9a8964f4f0416fbbee23303b84', 'https://www.si.edu/sites/default/files/styles/grid/public/snapshots/loretta_lynn_mashup_1.png?itok=pAOTYGwY&c=62cf038ea5b6d88ca5f1a68fc2a5c75f', 'https://www.si.edu/sites/default/files/styles/grid/public/snapshots/catlett_statues.jpeg?itok=reovm-Xu&c=3971c85c06b2abe8e0cd2c582f401804', 'https://www.si.edu/sites/default/files/styles/grid/public/snapshots/ethel_lois_payne_2.jpg?itok=pjF5puAG&c=cf3065ecfabd9a2d13d330dc84a63861', 'https://www.si.edu/sites/default/files/styles/grid/public/snapshots/deliveryservice-7.jpeg?itok=cZ3zLdzL&c=82c8014d616fe150ad69ff1ae87a4b5f', 'https://www.si.edu/sites/default/files/styles/grid/public/snapshots/beatrix_potter_gif_3.gif?itok=OekFW-DZ&c=0162a3813e7eb7794d2f8fe3d76761fe', 'https://www.si.edu/sites/default/files/styles/grid/public/snapshots/solar_probe_photo.jpg?itok=eEXU2l2d&c=1bd6bddc20eddccc934fe92dda791b03', 'https://www.si.edu/sites/default/files/styles/grid/public/snapshots/jetpack_photo.jpg?itok=eJI62agp&c=4f2ffa62d41eaff7e9e747fd3edcae42', 'https://www.si.edu/sites/default/files/styles/grid/public/snapshots/bat_photo.png?itok=3Ig6qhSV&c=f0bf1ca178401810493a5934f7908f68', 'https://www.si.edu/sites/default/files/styles/grid/public/snapshots/i_dreamed_carlos_almaraz_photo.jpg?itok=yF5J-eIY&c=e01baf637f9f95252ff6025d3a084d6d', 'https://www.si.edu/sites/default/files/styles/grid/public/snapshots/sept._11_photo.jpg?itok=wjA9NWt2&c=cc637cafcf61ce48b7517e66c704aa1f', 'https://www.si.edu/sites/default/files/styles/grid/public/snapshots/saul_steinberg_dog_cartoon_photo.jpg?itok=H6whX3tl&c=ce1f71e226042a70dda0b31e7f7ae83f', 'https://www.si.edu/sites/default/files/styles/grid/public/snapshots/captain_video_photo.png?itok=tOKMLuhV&c=3cf8bf541d7e59b421b2efb9e6a5b782', 'https://www.si.edu/sites/default/files/styles/grid/public/snapshots/jellyfish_photo.jpg?itok=lD9dDYxm&c=3f895ddb394bc9a92765e871d7d09071', 'https://www.si.edu/sites/default/files/styles/grid/public/snapshots/sleepy-cats-sil.png?itok=DlGrlrh-&c=22296f8a563f1d0413952fe48578c572', 'https://www.si.edu/sites/default/files/styles/grid/public/snapshots/x-wing_starfighter_photo.jpg?itok=pM63urM7&c=978da4aafee7630b419a9a8ca7463a4c', 'https://www.si.edu/sites/default/files/styles/grid/public/snapshots/harry_the_hipster_photo.jpg?itok=rDESJ8vl&c=1b02e2c3dc18245cbdb9204c4153bbfb', 'https://www.si.edu/sites/default/files/styles/grid/public/snapshots/butterfly_gif_3.gif?itok=veS8TDwZ&c=1db3d7c0d0675d43f2436241103ee861', 'https://www.si.edu/sites/default/files/styles/grid/public/snapshots/suzanne_asbury-oliver_photo.jpg?itok=KyhIfpRg&c=c83808fef22de765bb51f4e7df5b441a', 'https://www.si.edu/sites/default/files/styles/grid/public/snapshots/black_hole_mag_field_photo.png?itok=kcqsdYEX&c=00a75cad729fcfe9a96bb7effea9575c', 'https://www.si.edu/sites/default/files/styles/grid/public/snapshots/sister_rosetta_tharpe_photo.jpg?itok=je9j0q4z&c=6e7489bd9cb245a282128bdaeaa7865f', 'https://www.si.edu/sites/default/files/styles/grid/public/snapshots/augusta_savage_gamin_photo.jpg?itok=78z8zhRc&c=7cb92e015feac32fe050a7020332b5d2', 'https://logs1.smithsonian.museum/dcsuft0skadzpxvkk977nydg5_3r1t/njs.gif?dcsuri=/nojavascript&WT.js=No&WT.tv=10.4.23&dcssip=si.edu']
# Text (excerpt): Link to homepage Sign up for Smithsonian e-news
#
#
# Crawling https://www.si.edu/snapshot?page=2 at depth 2...
#
#
# Crawled Page Content:
# Anchors: [('Skip to main content', 'https://www.si.edu/snapshot?page=2#main-content'), ('My Visit', 'https://www.si.edu/myvisit'), ('Donate', 'http://go.si.edu/si-give'), ('Smithsonian Institution', 'https://www.si.edu/'), ('Visit', 'https://www.si.edu/visit'), ('Hours and Locations', 'https://www.si.edu/visit/hours'), ('Entry and Guidelines', 'https://www.si.edu/visit/tips'), ('Maps and Brochures', 'https://www.si.edu/visit/maps'), ('Dining and Shopping', 'https://www.si.edu/dining'), ('Accessibility', 'https://www.si.edu/visit/accessibility'), ('Visiting with Kids', 'https://www.si.edu/visit/kids'), ('Group Visits', 'https://www.si.edu/visit/groups'), ('Group Sales', 'https://www.si.edu/groupsales'), ("What's On", 'https://www.si.edu/whats-on'), ('Exhibitions', 'https://www.si.edu/exhibitions'), ('Current', 'https://www.si.edu/exhibitions'), ('Upcoming', 'https://www.si.edu/exhibitions/upcoming'), ('Past', 'https://www.si.edu/exhibitions/past'), ("Today's Events", 'https://www.si.edu/events/today'), ('Online Events', 'https://www.si.edu/events/online'), ('All Events', 'https://www.si.edu/events'), ('IMAX & Planetarium', 'https://www.si.edu/imax'), ('Explore', 'https://www.si.edu/explore'), ('- Art & Design', 'https://www.si.edu/explore/art'), ('- History & Culture', 'https://www.si.edu/explore/history'), ('- Science & Nature', 'https://www.si.edu/explore/science'), ('Collections', 'https://www.si.edu/collections'), ('Open Access', 'https://www.si.edu/openaccess'), ('Research Resources', 'https://www.si.edu/researchers'), ('Libraries', 'https://library.si.edu/'), ('Archives', 'https://www.si.edu/siasc'), ('Smithsonian Institution Archives', 'https://www.si.edu/siasc/si_archives'), ('Air and Space Museum', 'https://www.si.edu/siasc/nasm_archives'), ('Anacostia Community Museum', 'https://www.si.edu/siasc/acma'), ('American Art Museum', 'https://www.si.edu/siasc/saam'), ('Archives of American Art', 'https://www.si.edu/siasc/aaa'), ('Archives of American Gardens', 'https://www.si.edu/siasc/american_gardens'), ('American History Museum', 'https://www.si.edu/siasc/archives_center'), ('American Indian Museum', 'https://www.si.edu/siasc/nmai'), ('Asian Art Museum Archives', 'https://www.si.edu/siasc/freer_sackler'), ('Eliot Elisofon Photographic Archives, African Art', 'https://www.si.edu/siasc/eepa_nmafa'), ('Hirshhorn Archive', 'https://www.si.edu/siasc/hmsg_archive'), ('National Anthropological Archives', 'https://www.si.edu/siasc/naa'), ('National Portrait Gallery', 'https://www.si.edu/siasc/npg'), ('Ralph Rinzler Archives, Folklife', 'https://www.si.edu/siasc/rrfa_archive'), ("Libraries' Special Collections", 'https://www.si.edu/siasc/si_libraries'), ('Podcasts', 'https://www.si.edu/podcasts'), ('Mobile Apps', 'https://www.si.edu/mobile'), ('Learn', 'https://www.si.edu/learn'), ('For Caregivers', 'https://www.si.edu/learn/parents-and-caregivers'), ('For Educators', 'https://www.si.edu/educators'), ('Art & Design Resources', 'https://www.si.edu/educators/art-resources'), ('Science & Nature Resources', 'https://www.si.edu/educators/science-resources'), ('Social Studies & Civics Resources', 'https://www.si.edu/educators/social-studies-resources'), ('Professional Development', 'https://www.si.edu/educators/professional-development'), ('Events for Educators', 'https://www.si.edu/educators/events'), ('Field Trips', 'https://www.si.edu/visit/field-trip'), ('For Students', 'https://www.si.edu/learn/students'), ('For Academics', 'https://www.si.edu/learn/academics'), ('For Lifelong Learners', 'https://www.si.edu/learn/lifelong-learners'), ('Support Us', 'https://www.si.edu/support'), ('Become a Member', 'https://support.si.edu/site/Donation2/?df_id=18123&18123.donation=form1&s_formType=j&s_src=Z0000AW&s_subsrc=0000--eg--oa-oef--web--si-edu--top-nav--app--acq------support-nav--ow--&utm_campaign=0000--eg--oa-oef--web--si-edu--top-nav--app--acq------support-'), ('Renew Membership', 'https://support.si.edu/site/Donation2/?df_id=18123&18123. ...
# Images: ['https://www.si.edu/sites/all/themes/si_baseline/images/logos/logo.svg', 'https://www.si.edu/sites/default/files/snapshot-camera.jpg', 'https://www.si.edu/sites/default/files/styles/grid/public/snapshots/jupiter-like_planet_photo.jpg?itok=wOhqx6w1&c=338050928439ddebc681a970150ec1c1', 'https://www.si.edu/sites/default/files/styles/grid/public/snapshots/gold_nugget.jpg?itok=P0csm87_&c=eb84a5ab3024089c3ae05f9cbe79af77', 'https://www.si.edu/sites/default/files/styles/grid/public/snapshots/nmah-ahb2008q15018.jpg?itok=BdDrf5eF&c=bd8355a531263a43ae5121eca53a0762', 'https://www.si.edu/sites/default/files/styles/grid/public/snapshots/wonder_woman_invisible_jet_photo.jpg?itok=iNTWoJot&c=3143931c850190517baaadff4d0da65e', 'https://www.si.edu/sites/default/files/styles/grid/public/snapshots/leah_chase_chef_jacket_2.jpg?itok=OzBpwjdh&c=3cefc49a0645e1cd8c214d30a47e23fb', 'https://www.si.edu/sites/default/files/styles/grid/public/snapshots/navajo_code_talkers_bag_photo_2_0.png?itok=UGsmd23Y&c=152811ab695509565a91470d20066f3c', 'https://www.si.edu/sites/default/files/styles/grid/public/snapshots/dracula_stamp_photo.png?itok=osmhd2RM&c=56b203547213468560759b49c092de3f', 'https://www.si.edu/sites/default/files/styles/grid/public/snapshots/judi_oyama_photo.png?itok=bBkjYM81&c=59f41d9f04fbb637f0a3ffdbed190e04', 'https://www.si.edu/sites/default/files/styles/grid/public/snapshots/digital_postcards_fish_photo.jpg?itok=TSi4GJjv&c=8237659c840fe251de100ad598f70f1d', 'https://www.si.edu/sites/default/files/styles/grid/public/snapshots/tattoo_photo.jpg?itok=6DgJ8I94&c=e8977bb50ad9ecab7deeb6a1861ec032', 'https://www.si.edu/sites/default/files/styles/grid/public/snapshots/kinstugi_bowl.jpg?itok=D2XuPwHp&c=5244fe6f80a9f09847414d41c877d922', 'https://www.si.edu/sites/default/files/styles/grid/public/snapshots/preamble_wide_3.png?itok=iybc4hCU&c=053c575fd404fb1161207622979f9ced', 'https://www.si.edu/sites/default/files/styles/grid/public/snapshots/mrs._maisel_photo_1.jpg?itok=mezQW9Ej&c=f97a926d000beac8b8adaea9a342e1c1', 'https://www.si.edu/sites/default/files/styles/grid/public/snapshots/cowings_photo.jpg?itok=no1_j9ZR&c=5b8e59a167cc4d69c74402b726f13276', 'https://www.si.edu/sites/default/files/styles/grid/public/snapshots/basquiat_photo.jpg?itok=9bh0CcDp&c=dcbdaf497b7cab6803f0d84707d4adc0', 'https://www.si.edu/sites/default/files/styles/grid/public/snapshots/octavia_butler_typewriter_photo.jpg?itok=d1nar9Ni&c=6e6fa5c5b813c9dbd9e84fddf595df47', 'https://www.si.edu/sites/default/files/styles/grid/public/snapshots/obata_photo.jpg?itok=nR3oUXc0&c=92c384e7082008a78a28e14d7df59ce9', 'https://www.si.edu/sites/default/files/styles/grid/public/snapshots/corningware_casserole_dish.jpg?itok=2fYSG97j&c=dc5117d1c5bcba55608a06fb1cf23ddf', 'https://www.si.edu/sites/default/files/styles/grid/public/snapshots/pourier_belt_photo.jpg?itok=L7Gk8YUl&c=659eebe40c91406b94800aee9450a0e4', 'https://www.si.edu/sites/default/files/styles/grid/public/snapshots/frankenstein_photo_0.jpg?itok=uqM5Af5a&c=0c47d5de67f197725109db5ee3b6756b', 'https://www.si.edu/sites/default/files/styles/grid/public/snapshots/marisol_chalas_photo_0.png?itok=pv5zoAOs&c=ceb58e8004bf4679a2e8aab6b87198d0', 'https://www.si.edu/sites/default/files/styles/grid/public/snapshots/108562_ca4667ba3c68613f_b.jpg?itok=CJoDemxz&c=b27eab73c937f390a3f14b1030d8c116', 'https://www.si.edu/sites/default/files/styles/grid/public/snapshots/roller_derby_photo.jpg?itok=1IJldDZQ&c=0567d411a67b0b677b2ceed21650229e', 'https://www.si.edu/sites/default/files/styles/grid/public/snapshots/pink-fairy-armadillo.jpg?itok=RX0_FDB7&c=b606829bab09173ae03c37eff4fbbbd1', 'https://logs1.smithsonian.museum/dcsuft0skadzpxvkk977nydg5_3r1t/njs.gif?dcsuri=/nojavascript&WT.js=No&WT.tv=10.4.23&dcssip=si.edu']
# Text (excerpt): Link to homepage Sign up for Smithsonian e-news
#
#
# Crawling https://www.si.edu/snapshot?page=3 at depth 2...
#
#
# Crawled Page Content:
# Anchors: [('Skip to main content', 'https://www.si.edu/snapshot?page=3#main-content'), ('My Visit', 'https://www.si.edu/myvisit'), ('Donate', 'http://go.si.edu/si-give'), ('Smithsonian Institution', 'https://www.si.edu/'), ('Visit', 'https://www.si.edu/visit'), ('Hours and Locations', 'https://www.si.edu/visit/hours'), ('Entry and Guidelines', 'https://www.si.edu/visit/tips'), ('Maps and Brochures', 'https://www.si.edu/visit/maps'), ('Dining and Shopping', 'https://www.si.edu/dining'), ('Accessibility', 'https://www.si.edu/visit/accessibility'), ('Visiting with Kids', 'https://www.si.edu/visit/kids'), ('Group Visits', 'https://www.si.edu/visit/groups'), ('Group Sales', 'https://www.si.edu/groupsales'), ("What's On", 'https://www.si.edu/whats-on'), ('Exhibitions', 'https://www.si.edu/exhibitions'), ('Current', 'https://www.si.edu/exhibitions'), ('Upcoming', 'https://www.si.edu/exhibitions/upcoming'), ('Past', 'https://www.si.edu/exhibitions/past'), ("Today's Events", 'https://www.si.edu/events/today'), ('Online Events', 'https://www.si.edu/events/online'), ('All Events', 'https://www.si.edu/events'), ('IMAX & Planetarium', 'https://www.si.edu/imax'), ('Explore', 'https://www.si.edu/explore'), ('- Art & Design', 'https://www.si.edu/explore/art'), ('- History & Culture', 'https://www.si.edu/explore/history'), ('- Science & Nature', 'https://www.si.edu/explore/science'), ('Collections', 'https://www.si.edu/collections'), ('Open Access', 'https://www.si.edu/openaccess'), ('Research Resources', 'https://www.si.edu/researchers'), ('Libraries', 'https://library.si.edu/'), ('Archives', 'https://www.si.edu/siasc'), ('Smithsonian Institution Archives', 'https://www.si.edu/siasc/si_archives'), ('Air and Space Museum', 'https://www.si.edu/siasc/nasm_archives'), ('Anacostia Community Museum', 'https://www.si.edu/siasc/acma'), ('American Art Museum', 'https://www.si.edu/siasc/saam'), ('Archives of American Art', 'https://www.si.edu/siasc/aaa'), ('Archives of American Gardens', 'https://www.si.edu/siasc/american_gardens'), ('American History Museum', 'https://www.si.edu/siasc/archives_center'), ('American Indian Museum', 'https://www.si.edu/siasc/nmai'), ('Asian Art Museum Archives', 'https://www.si.edu/siasc/freer_sackler'), ('Eliot Elisofon Photographic Archives, African Art', 'https://www.si.edu/siasc/eepa_nmafa'), ('Hirshhorn Archive', 'https://www.si.edu/siasc/hmsg_archive'), ('National Anthropological Archives', 'https://www.si.edu/siasc/naa'), ('National Portrait Gallery', 'https://www.si.edu/siasc/npg'), ('Ralph Rinzler Archives, Folklife', 'https://www.si.edu/siasc/rrfa_archive'), ("Libraries' Special Collections", 'https://www.si.edu/siasc/si_libraries'), ('Podcasts', 'https://www.si.edu/podcasts'), ('Mobile Apps', 'https://www.si.edu/mobile'), ('Learn', 'https://www.si.edu/learn'), ('For Caregivers', 'https://www.si.edu/learn/parents-and-caregivers'), ('For Educators', 'https://www.si.edu/educators'), ('Art & Design Resources', 'https://www.si.edu/educators/art-resources'), ('Science & Nature Resources', 'https://www.si.edu/educators/science-resources'), ('Social Studies & Civics Resources', 'https://www.si.edu/educators/social-studies-resources'), ('Professional Development', 'https://www.si.edu/educators/professional-development'), ('Events for Educators', 'https://www.si.edu/educators/events'), ('Field Trips', 'https://www.si.edu/visit/field-trip'), ('For Students', 'https://www.si.edu/learn/students'), ('For Academics', 'https://www.si.edu/learn/academics'), ('For Lifelong Learners', 'https://www.si.edu/learn/lifelong-learners'), ('Support Us', 'https://www.si.edu/support'), ('Become a Member', 'https://support.si.edu/site/Donation2/?df_id=18123&18123.donation=form1&s_formType=j&s_src=Z0000AW&s_subsrc=0000--eg--oa-oef--web--si-edu--top-nav--app--acq------support-nav--ow--&utm_campaign=0000--eg--oa-oef--web--si-edu--top-nav--app--acq------support-'), ('Renew Membership', 'https://support.si.edu/site/Donation2/?df_id=18123&18123. ...
# Images: ['https://www.si.edu/sites/all/themes/si_baseline/images/logos/logo.svg', 'https://www.si.edu/sites/default/files/snapshot-camera.jpg', 'https://www.si.edu/sites/default/files/styles/grid/public/snapshots/apollo_11_suit_patch_2.jpg?itok=QLEhSqv6&c=3e74e8c1e04400a8a6d6a65bd9651ab0', 'https://www.si.edu/sites/default/files/styles/grid/public/snapshots/nmah-et2013-40197.jpg?itok=zIXpJKzZ&c=6e6f3f6cf9cacabf6ed0b24a55131d0e', 'https://www.si.edu/sites/default/files/styles/grid/public/snapshots/mothership_photo_mine.jpg?itok=q0RhAVWA&c=13fe868a1e6f8e4ad3712c0a7a998df0', 'https://www.si.edu/sites/default/files/styles/grid/public/snapshots/download.png?itok=BkV33Nt6&c=e731c6edbb955f989ea7b584c35d93c5', 'https://www.si.edu/sites/default/files/styles/grid/public/snapshots/dino_hall_photo_2_3.jpg?itok=Tdy_Sh2P&c=21778cea8ab975d2f2c2505cdff3ee4a', 'https://www.si.edu/sites/default/files/styles/grid/public/snapshots/duke_surfboard_photo_from_npg.jpg?itok=N3RfdNf3&c=a6e130ae23d7fd5274f15f2b21fb4a67', 'https://www.si.edu/sites/default/files/styles/grid/public/snapshots/tumblr_p6ddxyjk661rn3gulo1_540.gif?itok=9eEQt_OV&c=12c1301f65f9f864635541d36fc51d32', 'https://www.si.edu/sites/default/files/styles/grid/public/snapshots/20190410-78m-4000x2330.jpg?itok=-V7pqtGT&c=cca4184fa032ae907234ca7c7f112f40', 'https://www.si.edu/sites/default/files/styles/grid/public/snapshots/cixi_photo.jpg?itok=Jqr1tTU6&c=c06d359af1cfaa69970bf0e434a26e33', 'https://www.si.edu/sites/default/files/styles/grid/public/snapshots/vera_rubin_photo.jpg?itok=RrohobqC&c=ecf5c1be5ab445a23816ca3c81da1c7f', 'https://www.si.edu/sites/default/files/styles/grid/public/snapshots/comb-photo.jpg?itok=3oiJT9AK&c=a91cde06d5655626f0f85bc10076ed65', 'https://www.si.edu/sites/default/files/styles/grid/public/snapshots/saam-1995.40_1.jpg?itok=8q5iS6iQ&c=45398737b5c950bb8d301bc4f0fbd92e', 'https://www.si.edu/sites/default/files/styles/grid/public/snapshots/james-bond-cuban-tody-photo.jpg?itok=ZUzl2yA8&c=39ad23620e3d8b65c3b32a7ecd757313', 'https://www.si.edu/sites/default/files/styles/grid/public/snapshots/nmah-jn2013-1962-622x800.jpg?itok=lVjxEGFX&c=aae1dace3f3b7ab6bff880e770f16c7d', 'https://www.si.edu/sites/default/files/styles/grid/public/snapshots/bulldog-vision-photo.jpg?itok=2dEV-VIK&c=7912d53696bf6b0fa9d69187df75da3d', 'https://www.si.edu/sites/default/files/styles/grid/public/snapshots/lantern-shark-photo_0.jpg?itok=A7TZqMkY&c=a12b134bf21095709b4499ef702c6614', 'https://www.si.edu/sites/default/files/styles/grid/public/snapshots/ark_65665_m3ea18c9f4037a468f9acd94109f3ff679.jpg?itok=CXn4ohDk&c=3f4fe17397c8f49241c56a5213afd876', 'https://www.si.edu/sites/default/files/styles/grid/public/snapshots/npm-2000_2020_292.jpg?itok=u3ZnUgTL&c=3deab4ed309fca0cb1303fbd6c4c30a9', 'https://www.si.edu/sites/default/files/styles/grid/public/snapshots/nmah-ahb2009q10811.jpg?itok=Ubs3B9X6&c=f28e02f830cc2edc0a0a897890d0f305', 'https://www.si.edu/sites/default/files/styles/grid/public/snapshots/guardians-photo.png?itok=87huKGNW&c=03a2fee4d22d30aeb81ee2beb1c3709c', 'https://www.si.edu/sites/default/files/styles/grid/public/snapshots/1981-29-172-matt-flynn.png?itok=RcPsGJPp&c=d85fd58a5e4719983366feada611704d', 'https://www.si.edu/sites/default/files/styles/grid/public/snapshots/captain-america-shield-photo-630x420.jpeg?itok=8yqvD0XR&c=22ae41a9059cd13bf764eeb9a345966d', 'https://www.si.edu/sites/default/files/styles/grid/public/snapshots/suh-extinguisher-photo.jpeg?itok=udWPpuwZ&c=6cfe244672c246d60849944d2d87fc7d', 'https://www.si.edu/sites/default/files/styles/grid/public/snapshots/jackie-robinson-photo.jpg?itok=mcUyj-nm&c=9880f93179371c5aa157992e3a20abbc', 'https://logs1.smithsonian.museum/dcsuft0skadzpxvkk977nydg5_3r1t/njs.gif?dcsuri=/nojavascript&WT.js=No&WT.tv=10.4.23&dcssip=si.edu']
# Text (excerpt): Link to homepage Sign up for Smithsonian e-news
#
#
# Crawling https://www.si.edu/snapshot?page=4 at depth 2...
#
#
# Crawled Page Content:
# Anchors: [('Skip to main content', 'https://www.si.edu/snapshot?page=4#main-content'), ('My Visit', 'https://www.si.edu/myvisit'), ('Donate', 'http://go.si.edu/si-give'), ('Smithsonian Institution', 'https://www.si.edu/'), ('Visit', 'https://www.si.edu/visit'), ('Hours and Locations', 'https://www.si.edu/visit/hours'), ('Entry and Guidelines', 'https://www.si.edu/visit/tips'), ('Maps and Brochures', 'https://www.si.edu/visit/maps'), ('Dining and Shopping', 'https://www.si.edu/dining'), ('Accessibility', 'https://www.si.edu/visit/accessibility'), ('Visiting with Kids', 'https://www.si.edu/visit/kids'), ('Group Visits', 'https://www.si.edu/visit/groups'), ('Group Sales', 'https://www.si.edu/groupsales'), ("What's On", 'https://www.si.edu/whats-on'), ('Exhibitions', 'https://www.si.edu/exhibitions'), ('Current', 'https://www.si.edu/exhibitions'), ('Upcoming', 'https://www.si.edu/exhibitions/upcoming'), ('Past', 'https://www.si.edu/exhibitions/past'), ("Today's Events", 'https://www.si.edu/events/today'), ('Online Events', 'https://www.si.edu/events/online'), ('All Events', 'https://www.si.edu/events'), ('IMAX & Planetarium', 'https://www.si.edu/imax'), ('Explore', 'https://www.si.edu/explore'), ('- Art & Design', 'https://www.si.edu/explore/art'), ('- History & Culture', 'https://www.si.edu/explore/history'), ('- Science & Nature', 'https://www.si.edu/explore/science'), ('Collections', 'https://www.si.edu/collections'), ('Open Access', 'https://www.si.edu/openaccess'), ('Research Resources', 'https://www.si.edu/researchers'), ('Libraries', 'https://library.si.edu/'), ('Archives', 'https://www.si.edu/siasc'), ('Smithsonian Institution Archives', 'https://www.si.edu/siasc/si_archives'), ('Air and Space Museum', 'https://www.si.edu/siasc/nasm_archives'), ('Anacostia Community Museum', 'https://www.si.edu/siasc/acma'), ('American Art Museum', 'https://www.si.edu/siasc/saam'), ('Archives of American Art', 'https://www.si.edu/siasc/aaa'), ('Archives of American Gardens', 'https://www.si.edu/siasc/american_gardens'), ('American History Museum', 'https://www.si.edu/siasc/archives_center'), ('American Indian Museum', 'https://www.si.edu/siasc/nmai'), ('Asian Art Museum Archives', 'https://www.si.edu/siasc/freer_sackler'), ('Eliot Elisofon Photographic Archives, African Art', 'https://www.si.edu/siasc/eepa_nmafa'), ('Hirshhorn Archive', 'https://www.si.edu/siasc/hmsg_archive'), ('National Anthropological Archives', 'https://www.si.edu/siasc/naa'), ('National Portrait Gallery', 'https://www.si.edu/siasc/npg'), ('Ralph Rinzler Archives, Folklife', 'https://www.si.edu/siasc/rrfa_archive'), ("Libraries' Special Collections", 'https://www.si.edu/siasc/si_libraries'), ('Podcasts', 'https://www.si.edu/podcasts'), ('Mobile Apps', 'https://www.si.edu/mobile'), ('Learn', 'https://www.si.edu/learn'), ('For Caregivers', 'https://www.si.edu/learn/parents-and-caregivers'), ('For Educators', 'https://www.si.edu/educators'), ('Art & Design Resources', 'https://www.si.edu/educators/art-resources'), ('Science & Nature Resources', 'https://www.si.edu/educators/science-resources'), ('Social Studies & Civics Resources', 'https://www.si.edu/educators/social-studies-resources'), ('Professional Development', 'https://www.si.edu/educators/professional-development'), ('Events for Educators', 'https://www.si.edu/educators/events'), ('Field Trips', 'https://www.si.edu/visit/field-trip'), ('For Students', 'https://www.si.edu/learn/students'), ('For Academics', 'https://www.si.edu/learn/academics'), ('For Lifelong Learners', 'https://www.si.edu/learn/lifelong-learners'), ('Support Us', 'https://www.si.edu/support'), ('Become a Member', 'https://support.si.edu/site/Donation2/?df_id=18123&18123.donation=form1&s_formType=j&s_src=Z0000AW&s_subsrc=0000--eg--oa-oef--web--si-edu--top-nav--app--acq------support-nav--ow--&utm_campaign=0000--eg--oa-oef--web--si-edu--top-nav--app--acq------support-'), ('Renew Membership', 'https://support.si.edu/site/Donation2/?df_id=18123&18123. ...
# Images: ['https://www.si.edu/sites/all/themes/si_baseline/images/logos/logo.svg', 'https://www.si.edu/sites/default/files/snapshot-camera.jpg', 'https://www.si.edu/sites/default/files/styles/grid/public/snapshots/ginger-smock.png?itok=sDKHvjht&c=6b562eb52887c8f6dacf353b7e5d81a9', 'https://www.si.edu/sites/default/files/styles/grid/public/snapshots/dolores-huerta-photo-581x8001.jpg?itok=3k-FX9ZL&c=bd1df7b57ba64c9c4347e6ff61e729fc', 'https://www.si.edu/sites/default/files/styles/grid/public/snapshots/suffrage-pin-photo.jpg?itok=UcmyAk2i&c=1766046816b39783f8468fbeabc45bd3', 'https://www.si.edu/sites/default/files/styles/grid/public/snapshots/mister-rogers-sweater-photo-1-603x800.jpg?itok=TrTx87HQ&c=4ca8b21acb50c9cca56e92b2e1143a38', 'https://www.si.edu/sites/default/files/styles/grid/public/snapshots/hmsg-hmsg_19800107_20210309_001-000001.jpg?itok=UvJiSeb5&c=b83fbe3986eae38dd551d7957e785eab', 'https://www.si.edu/sites/default/files/styles/grid/public/snapshots/chauncey-spencer-photo-630x495.jpg?itok=fTVipMJP&c=8455b6db5e8207a26bc5299f7d159aad', 'https://www.si.edu/sites/default/files/styles/grid/public/snapshots/chsdm-0e8a84e924a12-000001.jpg?itok=-bTl7bZA&c=8a9a4ffca6d4f0f9ec934eb6f0d85de3', 'https://www.si.edu/sites/default/files/styles/grid/public/snapshots/bessie-coleman-photo-630x428.jpg?itok=shFt6fmw&c=20bbcd4f32e52097867b66ebc6b8373e', 'https://www.si.edu/sites/default/files/styles/grid/public/snapshots/pleiades-photo-gif.gif?itok=H_QBsUTl&c=8c462baecf54ea4caccbfaa369dc4ba3', 'https://www.si.edu/sites/default/files/styles/grid/public/snapshots/2018-01-16_snowflake_study.jpg?itok=T1iOAzkR&c=57a4f99049cbeffe44a64d31fc3917cb', 'https://www.si.edu/sites/default/files/styles/grid/public/snapshots/three_kings_photo.jpg?itok=q53N7bDU&c=75329a569a018ce5a076ad85b0077a21', 'https://www.si.edu/sites/default/files/styles/grid/public/snapshots/las_posadas_photo.jpg?itok=d1WispJn&c=3e450d803d711d29423263aac0164c38', 'https://www.si.edu/sites/default/files/styles/grid/public/snapshots/ch_steppenwolf_poster_photo.jpg?itok=zKlW7CFe&c=5709af4a9bf0efac327a91bce7f44fc4', 'https://www.si.edu/sites/default/files/styles/grid/public/snapshots/hamilton_suit_photo.jpg?itok=U49H4EMv&c=78c252cafff18c5af2b3f104a132fd7e', 'https://www.si.edu/sites/default/files/styles/grid/public/snapshots/owls_increase_and_diffusion.jpg?itok=mGILURgg&c=731f1ebfbb634b186ea16bbbc488f8f3', 'https://www.si.edu/sites/default/files/styles/grid/public/snapshots/tumblr_oejav3rwi81rn3gulo1_540.gif?itok=zMRctUuQ&c=ebad46c68b0355efc9b43e3ecb4665e0', 'https://www.si.edu/sites/default/files/styles/grid/public/snapshots/freer_stationery.jpg?itok=2RqQlbjB&c=3ad339efe90352b242960e11a8c76577', 'https://www.si.edu/sites/default/files/styles/grid/public/snapshots/cat_mummy_photo_2.png?itok=oaRLnDaH&c=c878a962fd095dba817e3a6080cd026a', 'https://www.si.edu/sites/default/files/styles/grid/public/snapshots/buddha_photo.jpg?itok=ssA_p316&c=87ee4103d228acf8e4bb903eeba83e55', 'https://www.si.edu/sites/default/files/styles/grid/public/snapshots/ac1351-0000001-003.jpg?itok=A-Q2R5Ap&c=5810313d7b8c4e8ee192b6d4515651ed', 'https://www.si.edu/sites/default/files/styles/grid/public/snapshots/2017-09-07_narwhal.gif?itok=LdWSQXxl&c=7059a1b0f7e6f64b1c9bacc393ad38f8', 'https://www.si.edu/sites/default/files/styles/grid/public/snapshots/winged-dog-630x4981.jpg?itok=BimeAPEw&c=f287692b46cd5d68b49b75faab64d93d', 'https://www.si.edu/sites/default/files/styles/grid/public/snapshots/cantiflas.jpg?itok=im04a4ru&c=193fa19b471188cc7d29b167139fc85c', 'https://www.si.edu/sites/default/files/styles/grid/public/snapshots/milky_way_photo_2.jpg?itok=ZX-IcyRr&c=33345326e8b04f122533a0c24dbbc151', 'https://logs1.smithsonian.museum/dcsuft0skadzpxvkk977nydg5_3r1t/njs.gif?dcsuri=/nojavascript&WT.js=No&WT.tv=10.4.23&dcssip=si.edu']
# Text (excerpt): Link to homepage Sign up for Smithsonian e-news
#
#
# Crawling https://www.si.edu/snapshot?page=5 at depth 2...
#
#
# Crawled Page Content:
# ...
# Text (excerpt): Link to homepage Sign up for Smithsonian e-news
#
#
# Crawling https://www.si.edu/snapshot?page=7 at depth 2...
#
#
# Crawled Page Content:
# Anchors: [('Skip to main content', 'https://www.si.edu/snapshot?page=7#main-content'), ('My Visit', 'https://www.si.edu/myvisit'), ('Donate', 'http://go.si.edu/si-give'), ('Smithsonian Institution', 'https://www.si.edu/'), ('Visit', 'https://www.si.edu/visit'), ('Hours and Locations', 'https://www.si.edu/visit/hours'), ('Entry and Guidelines', 'https://www.si.edu/visit/tips'), ('Maps and Brochures', 'https://www.si.edu/visit/maps'), ('Dining and Shopping', 'https://www.si.edu/dining'), ('Accessibility', 'https://www.si.edu/visit/accessibility'), ('Visiting with Kids', 'https://www.si.edu/visit/kids'), ('Group Visits', 'https://www.si.edu/visit/groups'), ('Group Sales', 'https://www.si.edu/groupsales'), ("What's On", 'https://www.si.edu/whats-on'), ('Exhibitions', 'https://www.si.edu/exhibitions'), ('Current', 'https://www.si.edu/exhibitions'), ('Upcoming', 'https://www.si.edu/exhibitions/upcoming'), ('Past', 'https://www.si.edu/exhibitions/past'), ("Today's Events", 'https://www.si.edu/events/today'), ('Online Events', 'https://www.si.edu/events/online'), ('All Events', 'https://www.si.edu/events'), ('IMAX & Planetarium', 'https://www.si.edu/imax'), ('Explore', 'https://www.si.edu/explore'), ('- Art & Design', 'https://www.si.edu/explore/art'), ('- History & Culture', 'https://www.si.edu/explore/history'), ('- Science & Nature', 'https://www.si.edu/explore/science'), ('Collections', 'https://www.si.edu/collections'), ('Open Access', 'https://www.si.edu/openaccess'), ('Research Resources', 'https://www.si.edu/researchers'), ('Libraries', 'https://library.si.edu/'), ('Archives', 'https://www.si.edu/siasc'), ('Smithsonian Institution Archives', 'https://www.si.edu/siasc/si_archives'), ('Air and Space Museum', 'https://www.si.edu/siasc/nasm_archives'), ('Anacostia Community Museum', 'https://www.si.edu/siasc/acma'), ('American Art Museum', 'https://www.si.edu/siasc/saam'), ('Archives of American Art', 'https://www.si.edu/siasc/aaa'), ('Archives of American Gardens', 'https://www.si.edu/siasc/american_gardens'), ('American History Museum', 'https://www.si.edu/siasc/archives_center'), ('American Indian Museum', 'https://www.si.edu/siasc/nmai'), ('Asian Art Museum Archives', 'https://www.si.edu/siasc/freer_sackler'), ('Eliot Elisofon Photographic Archives, African Art', 'https://www.si.edu/siasc/eepa_nmafa'), ('Hirshhorn Archive', 'https://www.si.edu/siasc/hmsg_archive'), ('National Anthropological Archives', 'https://www.si.edu/siasc/naa'), ('National Portrait Gallery', 'https://www.si.edu/siasc/npg'), ('Ralph Rinzler Archives, Folklife', 'https://www.si.edu/siasc/rrfa_archive'), ("Libraries' Special Collections", 'https://www.si.edu/siasc/si_libraries'), ('Podcasts', 'https://www.si.edu/podcasts'), ('Mobile Apps', 'https://www.si.edu/mobile'), ('Learn', 'https://www.si.edu/learn'), ('For Caregivers', 'https://www.si.edu/learn/parents-and-caregivers'), ('For Educators', 'https://www.si.edu/educators'), ('Art & Design Resources', 'https://www.si.edu/educators/art-resources'), ('Science & Nature Resources', 'https://www.si.edu/educators/science-resources'), ('Social Studies & Civics Resources', 'https://www.si.edu/educators/social-studies-resources'), ('Professional Development', 'https://www.si.edu/educators/professional-development'), ('Events for Educators', 'https://www.si.edu/educators/events'), ('Field Trips', 'https://www.si.edu/visit/field-trip'), ('For Students', 'https://www.si.edu/learn/students'), ('For Academics', 'https://www.si.edu/learn/academics'), ('For Lifelong Learners', 'https://www.si.edu/learn/lifelong-learners'), ('Support Us', 'https://www.si.edu/support'), ('Become a Member', 'https://support.si.edu/site/Donation2/?df_id=18123&18123.donation=form1&s_formType=j&s_src=Z0000AW&s_subsrc=0000--eg--oa-oef--web--si-edu--top-nav--app--acq------support-nav--ow--&utm_campaign=0000--eg--oa-oef--web--si-edu--top-nav--app--acq------support-'), ('Renew Membership', 'https://support.si.edu/site/Donation2/?df_id=18123&18123. ...
# Images: ['https://www.si.edu/sites/all/themes/si_baseline/images/logos/logo.svg', 'https://www.si.edu/sites/default/files/snapshot-camera.jpg', 'https://www.si.edu/sites/default/files/styles/grid/public/snapshots/mpt.jpg?itok=5QFLQ6T-&c=c5a27023a5badf30600bb0eaff110a80', 'https://www.si.edu/sites/default/files/styles/grid/public/snapshots/fantastic_worlds.gif?itok=QYGEzCvO&c=3562967e31328bb1ce866b765a052a6d', 'https://www.si.edu/sites/default/files/styles/grid/public/snapshots/closeup.jpg?itok=N8QLNJ6r&c=9d06dbcc611a1522c2f55317c2f3b174', 'https://www.si.edu/sites/default/files/styles/grid/public/snapshots/ada_2.jpeg?itok=JrS0JCc6&c=6da4922d474513f12f80fc467fce42df', 'https://www.si.edu/sites/default/files/styles/grid/public/snapshots/wish_tree_5.jpg?itok=zeq1C6wF&c=b5beb3435f8d586900f3bc1c9a3fbd76', 'https://www.si.edu/sites/default/files/styles/grid/public/snapshots/peony_snapshot.jpg?itok=IUQSMz8F&c=14844e34fc3adc57fe77c48ee1c23c4a', 'https://www.si.edu/sites/default/files/styles/grid/public/snapshots/c_npg_2013_84_36_white_r_2400x2404.jpg?itok=lIEEAlht&c=fc0eb6f87f87f73a4b2ff5d7bf47ca55', 'https://www.si.edu/sites/default/files/styles/grid/public/snapshots/filthy_lucre.gif?itok=7kVXBWI6&c=e4966c77a6506fbf288d4223b7319605', 'https://www.si.edu/sites/default/files/styles/grid/public/snapshots/big_jazz_painting_2004.jpg?itok=9ajKUC1K&c=53628efba3513e227c19b184ab287d16', 'https://www.si.edu/sites/default/files/styles/grid/public/snapshots/selenas_costume.jpg?itok=LrXLvsXA&c=2ce896c82e21377e2b4ae200ccb5017f', 'https://www.si.edu/sites/default/files/styles/grid/public/snapshots/cherry_blossoms.gif?itok=51AOPECa&c=a91945b822dd6ac9103476a60bb05444', 'https://www.si.edu/sites/default/files/styles/grid/public/snapshots/nmah-93-11496.jpg?itok=cOiFcg_2&c=0bee9c2990d88d5cb614d91ec3c0446b', 'https://www.si.edu/sites/default/files/styles/grid/public/snapshots/cropped_henson_painting.jpg?itok=hOR-miHm&c=228b1ae3aab89dffd1b35d9c347297cb', 'https://www.si.edu/sites/default/files/styles/grid/public/snapshots/cough_medicine.jpg?itok=LU6_U0h6&c=40335c47b760a63dc5fabf82706fbb66', 'https://www.si.edu/sites/default/files/styles/grid/public/snapshots/estes_diner.jpg?itok=uY7veTJf&c=a0e581c088cd0a1c6e88ca311c89072e', 'https://www.si.edu/sites/default/files/styles/grid/public/snapshots/spider.jpg?itok=1EF_a89P&c=5d5a74afbb99930d19e386ac6596cb5a', 'https://www.si.edu/sites/default/files/styles/grid/public/snapshots/dayofthedead.jpg?itok=mXC43FDJ&c=611e540a02cd840ee425a89b6c442185', 'https://www.si.edu/sites/default/files/styles/grid/public/snapshots/ceramica.jpg?itok=mD7S2e_9', 'https://www.si.edu/sites/default/files/styles/grid/public/snapshots/2014sotb_iiwi_jack_jeffrey_web.jpg?itok=jWahDNMd', 'https://www.si.edu/sites/default/files/styles/grid/public/snapshots/yardbomb2_0.jpg?itok=SF7AkfQq&c=bcfa9e8fcc4088c8d8ed0cfeaa1b4cbb', 'https://www.si.edu/sites/default/files/styles/grid/public/snapshots/dsc08630.jpg?itok=qz9NmAZF', 'https://www.si.edu/sites/default/files/styles/grid/public/snapshots/cone-headed-katydid.jpg?itok=zBVOxq9X&c=5dca0ebe485eff35938747b25064df36', 'https://www.si.edu/sites/default/files/styles/grid/public/snapshots/chigusa_3.gif?itok=Hg5VTAgl&c=95d8ef34d47f8314c17f2f4f93d3eb77', 'https://www.si.edu/sites/default/files/styles/grid/public/snapshots/snap_shot.jpg?itok=qmYd3rJM&c=65741ef6ff2f0feca677494258237328', 'https://logs1.smithsonian.museum/dcsuft0skadzpxvkk977nydg5_3r1t/njs.gif?dcsuri=/nojavascript&WT.js=No&WT.tv=10.4.23&dcssip=si.edu']
# Text (excerpt): Link to homepage Sign up for Smithsonian e-news
#
#
# Crawling https://www.si.edu/snapshot?page=8 at depth 2...
#
#
# Crawled Page Content:
# Anchors: [('Skip to main content', 'https://www.si.edu/snapshot?page=8#main-content'), ('My Visit', 'https://www.si.edu/myvisit'), ('Donate', 'http://go.si.edu/si-give'), ('Smithsonian Institution', 'https://www.si.edu/'), ('Visit', 'https://www.si.edu/visit'), ('Hours and Locations', 'https://www.si.edu/visit/hours'), ('Entry and Guidelines', 'https://www.si.edu/visit/tips'), ('Maps and Brochures', 'https://www.si.edu/visit/maps'), ('Dining and Shopping', 'https://www.si.edu/dining'), ('Accessibility', 'https://www.si.edu/visit/accessibility'), ('Visiting with Kids', 'https://www.si.edu/visit/kids'), ('Group Visits', 'https://www.si.edu/visit/groups'), ('Group Sales', 'https://www.si.edu/groupsales'), ("What's On", 'https://www.si.edu/whats-on'), ('Exhibitions', 'https://www.si.edu/exhibitions'), ('Current', 'https://www.si.edu/exhibitions'), ('Upcoming', 'https://www.si.edu/exhibitions/upcoming'), ('Past', 'https://www.si.edu/exhibitions/past'), ("Today's Events", 'https://www.si.edu/events/today'), ('Online Events', 'https://www.si.edu/events/online'), ('All Events', 'https://www.si.edu/events'), ('IMAX & Planetarium', 'https://www.si.edu/imax'), ('Explore', 'https://www.si.edu/explore'), ('- Art & Design', 'https://www.si.edu/explore/art'), ('- History & Culture', 'https://www.si.edu/explore/history'), ('- Science & Nature', 'https://www.si.edu/explore/science'), ('Collections', 'https://www.si.edu/collections'), ('Open Access', 'https://www.si.edu/openaccess'), ('Research Resources', 'https://www.si.edu/researchers'), ('Libraries', 'https://library.si.edu/'), ('Archives', 'https://www.si.edu/siasc'), ('Smithsonian Institution Archives', 'https://www.si.edu/siasc/si_archives'), ('Air and Space Museum', 'https://www.si.edu/siasc/nasm_archives'), ('Anacostia Community Museum', 'https://www.si.edu/siasc/acma'), ('American Art Museum', 'https://www.si.edu/siasc/saam'), ('Archives of American Art', 'https://www.si.edu/siasc/aaa'), ('Archives of American Gardens', 'https://www.si.edu/siasc/american_gardens'), ('American History Museum', 'https://www.si.edu/siasc/archives_center'), ('American Indian Museum', 'https://www.si.edu/siasc/nmai'), ('Asian Art Museum Archives', 'https://www.si.edu/siasc/freer_sackler'), ('Eliot Elisofon Photographic Archives, African Art', 'https://www.si.edu/siasc/eepa_nmafa'), ('Hirshhorn Archive', 'https://www.si.edu/siasc/hmsg_archive'), ('National Anthropological Archives', 'https://www.si.edu/siasc/naa'), ('National Portrait Gallery', 'https://www.si.edu/siasc/npg'), ('Ralph Rinzler Archives, Folklife', 'https://www.si.edu/siasc/rrfa_archive'), ("Libraries' Special Collections", 'https://www.si.edu/siasc/si_libraries'), ('Podcasts', 'https://www.si.edu/podcasts'), ('Mobile Apps', 'https://www.si.edu/mobile'), ('Learn', 'https://www.si.edu/learn'), ('For Caregivers', 'https://www.si.edu/learn/parents-and-caregivers'), ('For Educators', 'https://www.si.edu/educators'), ('Art & Design Resources', 'https://www.si.edu/educators/art-resources'), ('Science & Nature Resources', 'https://www.si.edu/educators/science-resources'), ('Social Studies & Civics Resources', 'https://www.si.edu/educators/social-studies-resources'), ('Professional Development', 'https://www.si.edu/educators/professional-development'), ('Events for Educators', 'https://www.si.edu/educators/events'), ('Field Trips', 'https://www.si.edu/visit/field-trip'), ('For Students', 'https://www.si.edu/learn/students'), ('For Academics', 'https://www.si.edu/learn/academics'), ('For Lifelong Learners', 'https://www.si.edu/learn/lifelong-learners'), ('Support Us', 'https://www.si.edu/support'), ('Become a Member', 'https://support.si.edu/site/Donation2/?df_id=18123&18123.donation=form1&s_formType=j&s_src=Z0000AW&s_subsrc=0000--eg--oa-oef--web--si-edu--top-nav--app--acq------support-nav--ow--&utm_campaign=0000--eg--oa-oef--web--si-edu--top-nav--app--acq------support-'), ('Renew Membership', 'https://support.si.edu/site/Donation2/?df_id=18123&18123. ...
# Images: ['https://www.si.edu/sites/all/themes/si_baseline/images/logos/logo.svg', 'https://www.si.edu/sites/default/files/snapshot-camera.jpg', 'https://www.si.edu/sites/default/files/styles/grid/public/snapshots/deborah_harry.jpg?itok=hb3W-QP3&c=3e390396016817bef23f12f5e142b4fd', 'https://www.si.edu/sites/default/files/styles/grid/public/snapshots/2006_2036_149_5.jpg?itok=LRBmqmBu&c=256a7789d825c7b8fb00410606332342', 'https://www.si.edu/sites/default/files/styles/grid/public/snapshots/coltrane_sax.jpg?itok=FR6L7GhA&c=e6cee61e983632d14587dba225c4ce31', 'https://www.si.edu/sites/default/files/styles/grid/public/snapshots/kiyochika.gif?itok=dc6PSuOx&c=d196c0c559b7e127d5ef184002abd5bd', 'https://www.si.edu/sites/default/files/styles/grid/public/snapshots/jimihendrix_mccartney.jpg?itok=jrQFkVXo&c=c0395169ae6ec46a15008f84e47b02a3', 'https://www.si.edu/sites/default/files/styles/grid/public/snapshots/ramirez_breakfast_tacos_0.jpg?itok=v7_MO5BU&c=3e450d803d711d29423263aac0164c38', 'https://www.si.edu/sites/default/files/styles/grid/public/snapshots/nmah-83-5968.jpg?itok=aPNsZTl5&c=65b201af9149e7c0258e2bc4ca4f7488', 'https://www.si.edu/sites/default/files/styles/grid/public/snapshots/saam-1996.91.59_1.jpg?itok=6opELjMx&c=5dd14eb047be1639ca3613bd82dd8bd6', 'https://www.si.edu/sites/default/files/styles/grid/public/snapshots/lady-bug-release-child-665.jpg?itok=lThVI62j&c=31b170312945fe4e780b2516c65657ca', 'https://www.si.edu/sites/default/files/styles/grid/public/snapshots/puli-sculpture.jpg?itok=wRUlvtIf&c=7c9819864510e5ae884b01bbe35109e9', 'https://www.si.edu/sites/default/files/styles/grid/public/snapshots/1976-microwave-animated-gif.gif?itok=FSsBhJ8t&c=bad8147e401c5dd9a7ea475fd26ad095', 'https://www.si.edu/sites/default/files/styles/grid/public/snapshots/saiab_coelocanth_665.jpg?itok=4e76vGTs&c=0e1b7aa1bfa3a9d11456e393ebd92309', 'https://www.si.edu/sites/default/files/styles/grid/public/snapshots/x-rayed-spacesuit.jpg?itok=MMN4J7P_&c=b5beb3435f8d586900f3bc1c9a3fbd76', 'https://www.si.edu/sites/default/files/styles/grid/public/snapshots/skylab-449.jpg?itok=XQtOjqR4', 'https://www.si.edu/sites/default/files/styles/grid/public/snapshots/odori-hitori-geiko.jpg?itok=rLPcyTeV&c=fc0eb6f87f87f73a4b2ff5d7bf47ca55', 'https://www.si.edu/sites/default/files/styles/grid/public/snapshots/nmah2004-01555_428px.jpg?itok=2zOUp9qc&c=042f4a0182cb31b9c7c26d2f39bb1d77', 'https://www.si.edu/sites/default/files/styles/grid/public/snapshots/postcard-1913-suffrage-parade.jpg?itok=WqX-wMZH&c=b72dcfd57c813d138208647fc549d4ae', 'https://www.si.edu/sites/default/files/styles/grid/public/snapshots/saam-collage.jpg?itok=dlQI6v4t&c=5ce5409c86ce95559df42c7860ec147a', 'https://www.si.edu/sites/default/files/styles/grid/public/snapshots/greensboro-lunch-counter.jpg?itok=XYr8StMQ&c=e42c43f192fe5586267e94d15651ced3', 'https://www.si.edu/sites/default/files/styles/grid/public/snapshots/santa-claus-express.jpg?itok=nGWIVJvF', 'https://www.si.edu/sites/default/files/styles/grid/public/snapshots/telescoping-shopping-carts.jpg?itok=LIsd402K&c=1f0110f864d5852b5b4b69682623ba3a', 'https://www.si.edu/sites/default/files/styles/grid/public/snapshots/saam_thanksgiving-menu_0.jpg?itok=1PC0SHMp&c=832e6b5e42f5f3f784cecba402c39588', 'https://www.si.edu/sites/default/files/styles/grid/public/snapshots/vampire-squid1.jpg?itok=e64nGSpY&c=6b72920de9145a92e55f969bd380b998', 'https://www.si.edu/sites/default/files/styles/grid/public/snapshots/hershey.jpg?itok=BQvyPX7i&c=9d8717b755e31c45642c56e8f9cb79ad', 'https://logs1.smithsonian.museum/dcsuft0skadzpxvkk977nydg5_3r1t/njs.gif?dcsuri=/nojavascript&WT.js=No&WT.tv=10.4.23&dcssip=si.edu']
# Text (excerpt): Link to homepage Sign up for Smithsonian e-news
